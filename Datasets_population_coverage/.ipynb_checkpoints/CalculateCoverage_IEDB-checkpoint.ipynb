# %%
import pandas as pd
import os
import pickle

# %% [markdown]
# ## Download and prepare the IEDB Population coverage tool
#
# 1. Download the population coverage tool from [here](http://tools.iedb.org/population/download/).
# 2. Untar the contents of the downloaded file to the root folder of this notebook.
# 3. The root folder of this notebook will contain the `population_coverage` folder.
# 4. Run the cell below to make sure you have a working version of the population coverage tool (you should see the usage output).

# %%
os.system("python ./population_coverage/calculate_population_coverage.py --help")
# Out:
# usage: python calculate_population_coverage.py [-h] -p [POPULATION] -c [MHC_CLASS] -f [FILE]
#
# Created on: 03/06/2017 @author: Dorjee Gyaltsen @brief: calculates population
# coverage - standalone version
#
# options:
#   -h, --help            show this help message and exit
#   --list                list all population and ethnicity
#   --plot PATH           generate a plot.
#   --version             show program's version number and exit
#
# required arguments:
#   -p POPULATION [POPULATION ...], --population POPULATION [POPULATION ...]
#                         select comma-separated area(s) or population(s)
#   -c MHC_CLASS [MHC_CLASS ...], --mhc_class MHC_CLASS [MHC_CLASS ...]
#                         select one or more comma-separated mhc class option -
#                         I, II, combined
#   -f FILE, --file FILE  a file containing a list of epitopes and associated
#                         alleles (comma-separated)
# 0

# %% [markdown]
# ####  Format the AFND frequencies in a pickle to be used by the IEDB pop coverage

# %%
afnd_df = pd.read_csv("AFND_data_locus_all.csv")
afnd_df.Population.unique()
afnd_df["Population"] = afnd_df["Population"].apply(lambda x: x.replace("á", "a")) 
afnd_df.to_csv("AFND_data_locus_all.csv")
from collections import OrderedDict
full_dict = OrderedDict()
for population in afnd_df.Population.unique():
    pop_dict = OrderedDict()
    for locus in afnd_df.Locus.unique():
        tmp_df = afnd_df[(afnd_df.Population==population) & (afnd_df.Locus==locus)]
        freqs = list(tmp_df.apply(lambda x: ("HLA-"+x.Allele, x["Allele Frequency"]), axis=1))
        pop_dict["HLA-{}".format(locus)] = freqs
    full_dict[population] = pop_dict
final_dict = {"I": full_dict}
with open("our_frequencies_pickle.p", "wb") as pickle_file:
    pickle.dump(final_dict, pickle_file)

# %% [markdown]
# #### Move this file to ./population_coverage rename it to match and replace the old file

# %%
#in linux:
os.system("cp ./our_frequencies_pickle.p  ./population_coverage/population_coverage_pickle/population_genotype_map.p")
# Out:
# 0

# %% [markdown]
# #### Fix the init file

# %%
init_file_content = '''
import pickle
from pkg_resources import resource_filename  # @UnresolvedImport

package_name = "population_coverage_pickle"
pickle_filename = "population_genotype_map.p"
pickle_file_path = resource_filename(package_name, pickle_filename)

with open(pickle_file_path, "rb") as pickle_file:
    population_coverage = pickle.load(pickle_file)
    #country_ethnicity = pickle.load(pickle_file)
    #ethnicity = pickle.load(pickle_file)
    country_ethnicity = population_coverage
    ethnicity = population_coverage
'''

init_file_location = "./population_coverage/population_coverage_pickle/__init__.py"

with open(init_file_location, "w") as tmp_file:
    tmp_file.write(init_file_content)

# %% [markdown]
# ## Run population coverage for each of our populations

# %%
import os
from pathlib import Path
import pandas as pd
import plotly.express as px
from numpy import trapz
from scipy.spatial import distance
import numpy as np

# %%
def append_n_peptides(ideal_n_peptides, allele, ideal_dataset):
    ideal_n_peptides = int(ideal_n_peptides)
    peptides = range(ideal_n_peptides)
    allele = row.Allele
    alleles = list(np.repeat(allele, ideal_n_peptides))
    ideal_dataset["peptide"].extend(peptides)
    ideal_dataset["allele"].extend(alleles)
    return ideal_dataset

def run_population_coverage(population, afnd_df, dataset_name, exec_file, output_directory="."):
    
    # calculate for the real dataset
    print("===============================")
    print("Calculating PC for {} for dataset {}".format(population, dataset_name))
    print("===============================")
    root = Path(output_directory)
    print("Saving outputs to: {}".format(root))
    root.mkdir(parents=True, exist_ok=True)
    
    population_tmp_name = population.replace(" ", "_")
    population_tmp_name = population_tmp_name.replace("/", "_")
    dataset_real = os.path.join(Path(os.getcwd()), Path("./datasets/{}.csv".format(dataset_name)))
    dataset_real_pd = pd.read_csv(dataset_real, header=None, sep="\t")
    dataset_real_pd.columns = ["peptide", "allele", "locus"]
    dataset_real_pd["locus"] = dataset_real_pd["allele"].apply(lambda x: x[x.find("-")+1:x.find("*")])
    dataset_real_pd = dataset_real_pd[dataset_real_pd.locus.isin(["A", "B", "C"])]
    dataset_peptide_n = dataset_real_pd.shape[0]
    dataset_allele_n = dataset_real_pd["allele"].unique().shape[0]
    dataset_locus_n = dataset_real_pd["locus"].unique().shape[0]
    print(dataset_real_pd)
    print("Looking at dataset {} with total {} peptides across {} alleles {} loci".format(dataset_name, \
                                                                                 dataset_peptide_n,\
                                                                                 dataset_allele_n, \
                                                                                 dataset_locus_n))
    
    output_file_real = os.path.join(root, "{}_{}_real.txt".format(dataset_name, population_tmp_name))
    command = "python {} -p \"{}\" -c I -f {} > {}".format(exec_file, population, dataset_real, output_file_real)
    print("Running IEDB tool for population coverage and saving output to: {}".format(output_file_real))
    print(command)
    os.system(command)
    print(output_file_real)
    res_pd_real = pd.read_csv(output_file_real, skiprows=6, sep="\t")
    
    # calculate for the ideal dataset
    print("===============================")
    print("Calculating PC for {} for ideal dataset {}".format(population, dataset_name))
    print("===============================")
    tmp_afnd_df = afnd_df[afnd_df.Population == population]
    tmp_afnd_df = tmp_afnd_df[tmp_afnd_df.Locus.isin(["A", "B", "C"])]
    locus_n = len(tmp_afnd_df["Locus"].unique())
    allele_n = len(tmp_afnd_df["Allele"].unique())
    print("The original dataset {} has {} peptides".format(dataset_name, dataset_peptide_n))
    print("The population has {} alleles across {} loci".format(allele_n, locus_n))
    tmp_afnd_df["ideal_n_peptides"] = tmp_afnd_df["Allele Frequency"].apply(lambda x: int((dataset_peptide_n * x)/locus_n))
    tmp_afnd_df = tmp_afnd_df.sort_values(by=["Allele", "Locus"])
    tmp_afnd_df = tmp_afnd_df[tmp_afnd_df.ideal_n_peptides > 0]
    ideal_dataset_df = tmp_afnd_df.loc[tmp_afnd_df.index.repeat(tmp_afnd_df.ideal_n_peptides)].reset_index(drop=True)
    ideal_dataset_df["peptide"] = ideal_dataset_df.index
    ideal_dataset_df["peptide"] =  ideal_dataset_df["peptide"].apply(lambda x: "pep_{}".format(x))
    ideal_dataset_df["allele"] = ideal_dataset_df.Allele.apply(lambda x: "HLA-{}".format(x))
    ideal_dataset_df = ideal_dataset_df[["peptide", "allele"]]
    ideal_dataset_file = os.path.join(root, Path("./{}_{}_ideal.csv".format(dataset_name, population_tmp_name)))
    ideal_dataset_df.to_csv(ideal_dataset_file, header=None, index=False, sep="\t")
    print("Ideal dataset has {} peptides across {} alleles".format(len(ideal_dataset_df.peptide),
                                                                       len(ideal_dataset_df.allele.unique())))
    print(tmp_afnd_df[["Allele", "Locus", "ideal_n_peptides"]].reset_index())
    
    print("Saved dummy ideal dataset to: {}".format(ideal_dataset_file))
    output_file_ideal = os.path.join(root, "{}_{}_ideal.txt".format(dataset_name, population_tmp_name))
    print("Running IEDB tool for population coverage and saving output to: {}".format(output_file_ideal))
    command = "python {} -p \"{}\" -c I -f {} > {}".format(exec_file, population, ideal_dataset_file, output_file_ideal)
    os.system(command)
    
    print("===============================")
    print("Plotting results")
    print("===============================")
    #plot and calculate differences
    res_pd_ideal = pd.read_csv(output_file_ideal, skiprows=6, sep="\t")
    
    res_pd_ideal["type"] = res_pd_ideal.epitope_hits.apply(lambda x: "ideal")
    res_pd_real["type"] = res_pd_real.epitope_hits.apply(lambda x: "real")
    res_pd_all = pd.concat([res_pd_ideal, res_pd_real])
    results_output = os.path.join(root, "{}_{}_results.csv".format(dataset_name, population_tmp_name))
    res_pd_all.to_csv(results_output)
    
    fig = px.scatter(res_pd_all\
             , x="epitope_hits", y="cumulative_coverage", color="type")
    #fig.show()
    results_fig_output = os.path.join(root, "{}_{}_plot.svg".format(dataset_name, population_tmp_name))
    fig.write_image(results_fig_output, width=1500, height=500)

    print("===============================")
    print("Calculating JS divergence")
    print("===============================")
    # Compute JS-divergence
    max_y = max(res_pd_real.epitope_hits.max(), res_pd_ideal.epitope_hits.max())
    y_real = list(res_pd_real.cumulative_coverage)
    y_ideal = list(res_pd_ideal.cumulative_coverage)
    max_y_len = max(len(y_real), len(y_ideal))
    y_real_fit = [y_real[i] if i<len(y_real) else 0 for i in range(max_y_len)]
    y_ideal_fit = [y_ideal[i] if i<len(y_ideal) else 0 for i in range(max_y_len)] 
    dist = distance.jensenshannon(y_real_fit, y_ideal_fit)
    print("JS divergence: {}".format(dist))
    return dist

# %% [markdown]
# ### Test for single population

# %%
from pathlib import Path

out_dir = "./iedb_afnd_pc_results"
exec_file = Path("./population_coverage/calculate_population_coverage.py")
tmp_res = run_population_coverage("American Samoa", afnd_df, "mhcflurry_peptides_ba", exec_file, ".")
# Out:
# ===============================
# Calculating PC for American Samoa for dataset mhcflurry_peptides_ba
# ===============================
# Saving outputs to: .
#            peptide       allele locus
# 0        AADFPGIAR  HLA-A*01:01     A
# 1       AADKAAAAAY  HLA-A*01:01     A
# 2        AADKAAAAY  HLA-A*01:01     A
# 3        AADSFATSY  HLA-A*01:01     A
# 4       AAELDRTEEY  HLA-A*01:01     A
# ...            ...          ...   ...
# 165527   YVYFYDLSY  HLA-C*15:02     C
# 165528   YWMGGTTYF  HLA-C*15:02     C
# 165529   YYFSYPLFV  HLA-C*15:02     C
# 165530   YYGRWVHEF  HLA-C*15:02     C
# 165531   YYKKTFSAL  HLA-C*15:02     C
#
# [165532 rows x 3 columns]
# Looking at dataset mhcflurry_peptides_ba with total 165532 peptides across 131 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: ./mhcflurry_peptides_ba_American_Samoa_real.txt
# python population_coverage/calculate_population_coverage.py -p "American Samoa" -c I -f /home/anja/Documents/HLAequity/HLAlleleBias/Datasets_population_coverage/datasets/mhcflurry_peptides_ba.csv > ./mhcflurry_peptides_ba_American_Samoa_real.txt
# ./mhcflurry_peptides_ba_American_Samoa_real.txt
# ===============================
# Calculating PC for American Samoa for ideal dataset mhcflurry_peptides_ba
# ===============================
# The original dataset mhcflurry_peptides_ba has 165532 peptides
# The population has 56 alleles across 3 loci
# Ideal dataset has 163844 peptides across 56 alleles
#     index   Allele Locus  ideal_n_peptides
# 0       0  A*02:01     A              7173
# 1       1  A*02:06     A              7173
# 2       2  A*03:01     A              1103
# 3       3  A*11:01     A              8828
# 4       4  A*11:04     A               551
# 5       5  A*24:02     A             18208
# 6       6  A*24:04     A               551
# 7       7  A*24:08     A              1103
# 8       8  A*26:01     A              3310
# 9       9  A*31:01     A               551
# 10     10  A*34:01     A              5517
# 11     11  A*66:01     A               551
# 12     12  A*68:03     A               551
# 13  15099  B*07:02     B               551
# 14  15100  B*08:03     B               551
# 15  15101  B*13:01     B               551
# 16  15102  B*15:02     B               551
# 17  15103  B*15:03     B               551
# 18  15104  B*15:06     B               551
# 19  15105  B*15:21     B              1655
# 20  15106  B*15:31     B              2207
# 21  15107  B*38:01     B               551
# 22  15108  B*39:01     B              2207
# 23  15109  B*40:01     B             16001
# 24  15110  B*40:02     B              1655
# 25  15111  B*40:08     B               551
# 26  15112  B*40:10     B               551
# 27  15113  B*40:11     B               551
# 28  15114  B*40:12     B               551
# 29  15115  B*40:14     B               551
# 30  15116  B*48:01     B              5517
# 31  15117  B*48:03     B              3310
# 32  15118  B*55:02     B              6621
# 33  15119  B*55:04     B              1655
# 34  15120  B*56:01     B              1103
# 35  15121  B*56:02     B              5517
# 36  15122  B*56:04     B               551
# 37  15123  B*67:01     B               551
# 38  40274  C*01:02     C             13242
# 39  40275  C*01:03     C              1103
# 40  40276  C*03:03     C              1103
# 41  40277  C*03:04     C              9931
# 42  40278  C*03:07     C              1655
# 43  40279  C*04:01     C              2207
# 44  40280  C*04:03     C              3310
# 45  40281  C*04:07     C              1103
# 46  40282  C*07:01     C               551
# 47  40283  C*07:02     C              4414
# 48  40284  C*08:01     C              8276
# 49  40285  C*08:02     C               551
# 50  40286  C*12:03     C              1103
# 51  40287  C*15:03     C               551
# 52  40288  C*15:05     C               551
# 53  40289  C*15:07     C              2207
# 54  40290  C*15:08     C               551
# 55  40291  C*16:04     C              1103
# Saved dummy ideal dataset to: ./mhcflurry_peptides_ba_American_Samoa_ideal.csv
# Running IEDB tool for population coverage and saving output to: ./mhcflurry_peptides_ba_American_Samoa_ideal.txt
# ===============================
# Plotting results
# ===============================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       3 out_dir = "./iedb_afnd_pc_results"
#       4 exec_file = Path("./population_coverage/calculate_population_coverage.py")
# ----> 5 tmp_res = run_population_coverage("American Samoa", afnd_df, "mhcflurry_peptides_ba", exec_file, ".")
#
# Cell In[11], line 90, in run_population_coverage(population, afnd_df, dataset_name, exec_file, output_directory)
#      88 #fig.show()
#      89 results_fig_output = os.path.join(root, "{}_{}_plot.svg".format(dataset_name, population_tmp_name))
# ---> 90 fig.write_image(results_fig_output, width=1500, height=500)
#      92 print("===============================")
#      93 print("Calculating JS divergence")
#
# File ~/miniconda3/envs/hla-equity/lib/python3.11/site-packages/plotly/basedatatypes.py:3840, in BaseFigure.write_image(self, *args, **kwargs)
#    3780 """
#    3781 Convert a figure to a static image and write it to a file or writeable
#    3782 object
#    (...)
#    3836 None
#    3837 """
#    3838 import plotly.io as pio
# -> 3840 return pio.write_image(self, *args, **kwargs)
#
# File ~/miniconda3/envs/hla-equity/lib/python3.11/site-packages/plotly/io/_kaleido.py:267, in write_image(fig, file, format, scale, width, height, validate, engine)
#     251             raise ValueError(
#     252                 """
#     253 Cannot infer image type from output path '{file}'.
#    (...)
#     261                 )
#     262             )
#     264     # Request image
#     265     # -------------
#     266     # Do this first so we don't create a file if image conversion fails
# --> 267     img_data = to_image(
#     268         fig,
#     269         format=format,
#     270         scale=scale,
#     271         width=width,
#     272         height=height,
#     273         validate=validate,
#     274         engine=engine,
#     275     )
#     277     # Open file
#     278     # ---------
#     279     if path is None:
#     280         # We previously failed to make sense of `file` as a pathlib object.
#     281         # Attempt to write to `file` as an open file descriptor.
#
# File ~/miniconda3/envs/hla-equity/lib/python3.11/site-packages/plotly/io/_kaleido.py:133, in to_image(fig, format, width, height, scale, validate, engine)
#     131     # Raise informative error message if Kaleido is not installed
#     132     if scope is None:
# --> 133         raise ValueError(
#     134             """
#     135 Image export using the "kaleido" engine requires the kaleido package,
#     136 which can be installed using pip:
#     137     $ pip install -U kaleido
#     138 """
#     139         )
#     141     # Validate figure
#     142     # ---------------
#     143     fig_dict = validate_coerce_fig_to_dict(fig, validate)
#
# ValueError:
# Image export using the "kaleido" engine requires the kaleido package,
# which can be installed using pip:
#     $ pip install -U kaleido

# %% [markdown]
# ### Run for all populations

# %%
import numpy as np
# - if you want to restart from middle
#all_populations = afnd_df.Population.unique()
#np.argwhere(all_populations=='Russia Bering Island Aleuts')
#all_populations = all_populations[166:]

# %%
all_populations = afnd_df.Population.unique()
all_datasets = ["mhcflurry_peptides_ba", "netmhc_peptides_ba"]
out_dir = "./iedb_afnd_pc_results"
exec_file = Path("./population_coverage/calculate_population_coverage.py")

results = {"population": [], "dataset": [], "js_div": []}
failed = {"population": [], "dataset": []}
for population in all_populations:
    for dataset in all_datasets:
        try:
            res = run_population_coverage(population, afnd_df, dataset, exec_file, out_dir)
            results["population"].append(population)
            results["dataset"].append(dataset)
            results["js_div"].append(res)
        except:
            print("Failed for {}".format(population))
            failed["population"].append(population)
            failed["dataset"].append(dataset)
            
pd.DataFrame(results).to_csv(out_dir+"/all_results.csv")
# Out:
# ===============================
# Calculating PC for American Samoa for dataset mhcflurry
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AADFPGIAR  HLA-A*01:01     A
# 1       AADKAAAAAY  HLA-A*01:01     A
# 2        AADKAAAAY  HLA-A*01:01     A
# 3        AADSFATSY  HLA-A*01:01     A
# 4       AAELDRTEEY  HLA-A*01:01     A
# ...            ...          ...   ...
# 187590   YVYFYDLSY  HLA-C*15:02     C
# 187591   YWMGGTTYF  HLA-C*15:02     C
# 187592   YYFSYPLFV  HLA-C*15:02     C
# 187593   YYGRWVHEF  HLA-C*15:02     C
# 187594   YYKKTFSAL  HLA-C*15:02     C
#
# [187485 rows x 3 columns]
# Looking at dataset mhcflurry with total 187485 peptides across 132 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_American_Samoa_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "American Samoa" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\mhcflurry_peptides.csv > iedb_afnd_pc_results\mhcflurry_American_Samoa_real.txt
# iedb_afnd_pc_results\mhcflurry_American_Samoa_real.txt
# ===============================
# Calculating PC for American Samoa for ideal dataset mhcflurry
# ===============================
# The original dataset mhcflurry has 187485 peptides
# The population has 56 alleles across 3 loci
# Ideal dataset has 185566 peptides across 56 alleles
#     index   Allele Locus  ideal_n_peptides
# 0       0  A*02:01     A              8124
# 1       1  A*02:06     A              8124
# 2       2  A*03:01     A              1249
# 3       3  A*11:01     A              9999
# 4       4  A*11:04     A               624
# 5       5  A*24:02     A             20623
# 6       6  A*24:04     A               624
# 7       7  A*24:08     A              1249
# 8       8  A*26:01     A              3749
# 9       9  A*31:01     A               624
# 10     10  A*34:01     A              6249
# 11     11  A*66:01     A               624
# 12     12  A*68:03     A               624
# 13  15099  B*07:02     B               624
# 14  15100  B*08:03     B               624
# 15  15101  B*13:01     B               624
# 16  15102  B*15:02     B               624
# 17  15103  B*15:03     B               624
# 18  15104  B*15:06     B               624
# 19  15105  B*15:21     B              1874
# 20  15106  B*15:31     B              2499
# 21  15107  B*38:01     B               624
# 22  15108  B*39:01     B              2499
# 23  15109  B*40:01     B             18123
# 24  15110  B*40:02     B              1874
# 25  15111  B*40:08     B               624
# 26  15112  B*40:10     B               624
# 27  15113  B*40:11     B               624
# 28  15114  B*40:12     B               624
# 29  15115  B*40:14     B               624
# 30  15116  B*48:01     B              6249
# 31  15117  B*48:03     B              3749
# 32  15118  B*55:02     B              7499
# 33  15119  B*55:04     B              1874
# 34  15120  B*56:01     B              1249
# 35  15121  B*56:02     B              6249
# 36  15122  B*56:04     B               624
# 37  15123  B*67:01     B               624
# 38  40274  C*01:02     C             14998
# 39  40275  C*01:03     C              1249
# 40  40276  C*03:03     C              1249
# 41  40277  C*03:04     C             11249
# 42  40278  C*03:07     C              1874
# 43  40279  C*04:01     C              2499
# 44  40280  C*04:03     C              3749
# 45  40281  C*04:07     C              1249
# 46  40282  C*07:01     C               624
# 47  40283  C*07:02     C              4999
# 48  40284  C*08:01     C              9374
# 49  40285  C*08:02     C               624
# 50  40286  C*12:03     C              1249
# 51  40287  C*15:03     C               624
# 52  40288  C*15:05     C               624
# 53  40289  C*15:07     C              2499
# 54  40290  C*15:08     C               624
# 55  40291  C*16:04     C              1249
# Saved dummy ideal dataset to: iedb_afnd_pc_results\mhcflurry_American_Samoa_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_American_Samoa_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.4259128312012929
# ===============================
# Calculating PC for American Samoa for dataset netmhc
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AAAAFEAAL  HLA-B*48:01     B
# 1        AAAAFEAAL  HLA-C*14:02     C
# 2        AAADFAHAE  HLA-B*44:03     B
# 3        AAAKTPVIV  HLA-A*02:01     A
# 4        AAAKTPVIV  HLA-A*68:02     A
# ...            ...          ...   ...
# 170465  YDGRYWTMWK  HLA-C*08:03     C
# 170466   YEPSQSAQL  HLA-B*55:01     B
# 170467    YKKEQTLK  HLA-B*55:01     B
# 170468  YLRMRRTAAL  HLA-B*15:10     B
# 170469    YVALDFEQ  HLA-C*08:03     C
#
# [170107 rows x 3 columns]
# Looking at dataset netmhc with total 170107 peptides across 109 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_American_Samoa_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "American Samoa" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\netmhc_peptides.csv > iedb_afnd_pc_results\netmhc_American_Samoa_real.txt
# iedb_afnd_pc_results\netmhc_American_Samoa_real.txt
# ===============================
# Calculating PC for American Samoa for ideal dataset netmhc
# ===============================
# The original dataset netmhc has 170107 peptides
# The population has 56 alleles across 3 loci
# Ideal dataset has 168399 peptides across 56 alleles
#     index   Allele Locus  ideal_n_peptides
# 0       0  A*02:01     A              7371
# 1       1  A*02:06     A              7371
# 2       2  A*03:01     A              1134
# 3       3  A*11:01     A              9072
# 4       4  A*11:04     A               567
# 5       5  A*24:02     A             18711
# 6       6  A*24:04     A               567
# 7       7  A*24:08     A              1134
# 8       8  A*26:01     A              3402
# 9       9  A*31:01     A               567
# 10     10  A*34:01     A              5670
# 11     11  A*66:01     A               567
# 12     12  A*68:03     A               567
# 13  15099  B*07:02     B               567
# 14  15100  B*08:03     B               567
# 15  15101  B*13:01     B               567
# 16  15102  B*15:02     B               567
# 17  15103  B*15:03     B               567
# 18  15104  B*15:06     B               567
# 19  15105  B*15:21     B              1701
# 20  15106  B*15:31     B              2268
# 21  15107  B*38:01     B               567
# 22  15108  B*39:01     B              2268
# 23  15109  B*40:01     B             16443
# 24  15110  B*40:02     B              1701
# 25  15111  B*40:08     B               567
# 26  15112  B*40:10     B               567
# 27  15113  B*40:11     B               567
# 28  15114  B*40:12     B               567
# 29  15115  B*40:14     B               567
# 30  15116  B*48:01     B              5670
# 31  15117  B*48:03     B              3402
# 32  15118  B*55:02     B              6804
# 33  15119  B*55:04     B              1701
# 34  15120  B*56:01     B              1134
# 35  15121  B*56:02     B              5670
# 36  15122  B*56:04     B               567
# 37  15123  B*67:01     B               567
# 38  40274  C*01:02     C             13608
# 39  40275  C*01:03     C              1134
# 40  40276  C*03:03     C              1134
# 41  40277  C*03:04     C             10206
# 42  40278  C*03:07     C              1701
# 43  40279  C*04:01     C              2268
# 44  40280  C*04:03     C              3402
# 45  40281  C*04:07     C              1134
# 46  40282  C*07:01     C               567
# 47  40283  C*07:02     C              4536
# 48  40284  C*08:01     C              8505
# 49  40285  C*08:02     C               567
# 50  40286  C*12:03     C              1134
# 51  40287  C*15:03     C               567
# 52  40288  C*15:05     C               567
# 53  40289  C*15:07     C              2268
# 54  40290  C*15:08     C               567
# 55  40291  C*16:04     C              1134
# Saved dummy ideal dataset to: iedb_afnd_pc_results\netmhc_American_Samoa_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_American_Samoa_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.5032643364599204
# ===============================
# Calculating PC for American Samoa for dataset hlathena
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#              peptide       allele locus
# 0         AIDNSRNILY  HLA-A*01:01     A
# 1       AIGTYLDQYIVY  HLA-A*01:01     A
# 2          ALDDFTICY  HLA-A*01:01     A
# 3         ALDDFTICYF  HLA-A*01:01     A
# 4         ALDENGNLWY  HLA-A*01:01     A
# ...              ...          ...   ...
# 142295     YTSRIVVRL  HLA-C*17:01     C
# 142296     YVAPKAVWL  HLA-C*17:01     C
# 142297     YVAPRRILL  HLA-C*17:01     C
# 142298     YVVPYTIHL  HLA-C*17:01     C
# 142299     YVYKNVSQL  HLA-C*17:01     C
#
# [142300 rows x 3 columns]
# Looking at dataset hlathena with total 142300 peptides across 92 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_American_Samoa_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "American Samoa" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\hlathena_peptides.csv > iedb_afnd_pc_results\hlathena_American_Samoa_real.txt
# iedb_afnd_pc_results\hlathena_American_Samoa_real.txt
# ===============================
# Calculating PC for American Samoa for ideal dataset hlathena
# ===============================
# The original dataset hlathena has 142300 peptides
# The population has 56 alleles across 3 loci
# Ideal dataset has 140859 peptides across 56 alleles
#     index   Allele Locus  ideal_n_peptides
# 0       0  A*02:01     A              6166
# 1       1  A*02:06     A              6166
# 2       2  A*03:01     A               948
# 3       3  A*11:01     A              7589
# 4       4  A*11:04     A               474
# 5       5  A*24:02     A             15653
# 6       6  A*24:04     A               474
# 7       7  A*24:08     A               948
# 8       8  A*26:01     A              2846
# 9       9  A*31:01     A               474
# 10     10  A*34:01     A              4743
# 11     11  A*66:01     A               474
# 12     12  A*68:03     A               474
# 13  15099  B*07:02     B               474
# 14  15100  B*08:03     B               474
# 15  15101  B*13:01     B               474
# 16  15102  B*15:02     B               474
# 17  15103  B*15:03     B               474
# 18  15104  B*15:06     B               474
# 19  15105  B*15:21     B              1423
# 20  15106  B*15:31     B              1897
# 21  15107  B*38:01     B               474
# 22  15108  B*39:01     B              1897
# 23  15109  B*40:01     B             13755
# 24  15110  B*40:02     B              1423
# 25  15111  B*40:08     B               474
# 26  15112  B*40:10     B               474
# 27  15113  B*40:11     B               474
# 28  15114  B*40:12     B               474
# 29  15115  B*40:14     B               474
# 30  15116  B*48:01     B              4743
# 31  15117  B*48:03     B              2846
# 32  15118  B*55:02     B              5692
# 33  15119  B*55:04     B              1423
# 34  15120  B*56:01     B               948
# 35  15121  B*56:02     B              4743
# 36  15122  B*56:04     B               474
# 37  15123  B*67:01     B               474
# 38  40274  C*01:02     C             11384
# 39  40275  C*01:03     C               948
# 40  40276  C*03:03     C               948
# 41  40277  C*03:04     C              8538
# 42  40278  C*03:07     C              1423
# 43  40279  C*04:01     C              1897
# 44  40280  C*04:03     C              2846
# 45  40281  C*04:07     C               948
# 46  40282  C*07:01     C               474
# 47  40283  C*07:02     C              3794
# 48  40284  C*08:01     C              7115
# 49  40285  C*08:02     C               474
# 50  40286  C*12:03     C               948
# 51  40287  C*15:03     C               474
# 52  40288  C*15:05     C               474
# 53  40289  C*15:07     C              1897
# 54  40290  C*15:08     C               474
# 55  40291  C*16:04     C               948
# Saved dummy ideal dataset to: iedb_afnd_pc_results\hlathena_American_Samoa_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_American_Samoa_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.6204484325963758
# ===============================
# Calculating PC for Australia Cape York Peninsula Aborigine for dataset mhcflurry
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AADFPGIAR  HLA-A*01:01     A
# 1       AADKAAAAAY  HLA-A*01:01     A
# 2        AADKAAAAY  HLA-A*01:01     A
# 3        AADSFATSY  HLA-A*01:01     A
# 4       AAELDRTEEY  HLA-A*01:01     A
# ...            ...          ...   ...
# 187590   YVYFYDLSY  HLA-C*15:02     C
# 187591   YWMGGTTYF  HLA-C*15:02     C
# 187592   YYFSYPLFV  HLA-C*15:02     C
# 187593   YYGRWVHEF  HLA-C*15:02     C
# 187594   YYKKTFSAL  HLA-C*15:02     C
#
# [187485 rows x 3 columns]
# Looking at dataset mhcflurry with total 187485 peptides across 132 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Australia_Cape_York_Peninsula_Aborigine_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia Cape York Peninsula Aborigine" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\mhcflurry_peptides.csv > iedb_afnd_pc_results\mhcflurry_Australia_Cape_York_Peninsula_Aborigine_real.txt
# iedb_afnd_pc_results\mhcflurry_Australia_Cape_York_Peninsula_Aborigine_real.txt
# ===============================
# Calculating PC for Australia Cape York Peninsula Aborigine for ideal dataset mhcflurry
# ===============================
# The original dataset mhcflurry has 187485 peptides
# The population has 46 alleles across 3 loci
# Ideal dataset has 187521 peptides across 46 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      13  A*01:01     A              3312
# 1      14  A*02:01     A             10936
# 2      15  A*03:01     A              2749
# 3      16  A*11:01     A             11249
# 4      17  A*24:02     A             13936
# 5      18  A*31:01     A               312
# 6      19  A*32:01     A              1187
# 7      20  A*33:03     A               312
# 8      21  A*34:01     A             18186
# 9      22  A*68:01     A               312
# 10  15124  B*07:02     B              2812
# 11  15125  B*08:01     B              2187
# 12  15126  B*13:01     B             16873
# 13  15127  B*14:01     B               312
# 14  15128  B*15:06     B               937
# 15  15129  B*15:21     B              8436
# 16  15130  B*18:01     B               624
# 17  15131  B*27:05     B               312
# 18  15132  B*35:01     B               312
# 19  15133  B*35:03     B               312
# 20  15134  B*38:01     B              1249
# 21  15135  B*39:01     B              2187
# 22  15136  B*40:01     B              4999
# 23  15137  B*40:02     B              4999
# 24  15138  B*44:02     B              1562
# 25  15139  B*48:01     B               312
# 26  15140  B*55:01     B               312
# 27  15141  B*56:01     B             10311
# 28  15142  B*56:02     B              1874
# 29  15143  B*57:01     B               937
# 30  15144  B*58:01     B               624
# 31  40292  C*01:02     C             11561
# 32  40293  C*02:02     C               374
# 33  40294  C*03:02     C               374
# 34  40295  C*03:03     C              1749
# 35  40296  C*03:04     C              1374
# 36  40297  C*04:01     C             17186
# 37  40298  C*04:03     C              9811
# 38  40299  C*05:01     C              2124
# 39  40300  C*06:02     C              1749
# 40  40301  C*07:01     C              2124
# 41  40302  C*07:02     C              5999
# 42  40303  C*07:04     C               374
# 43  40304  C*08:01     C               374
# 44  40305  C*12:03     C              3187
# 45  40306  C*15:02     C              4187
# Saved dummy ideal dataset to: iedb_afnd_pc_results\mhcflurry_Australia_Cape_York_Peninsula_Aborigine_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Australia_Cape_York_Peninsula_Aborigine_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.4480874451587635
# ===============================
# Calculating PC for Australia Cape York Peninsula Aborigine for dataset netmhc
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AAAAFEAAL  HLA-B*48:01     B
# 1        AAAAFEAAL  HLA-C*14:02     C
# 2        AAADFAHAE  HLA-B*44:03     B
# 3        AAAKTPVIV  HLA-A*02:01     A
# 4        AAAKTPVIV  HLA-A*68:02     A
# ...            ...          ...   ...
# 170465  YDGRYWTMWK  HLA-C*08:03     C
# 170466   YEPSQSAQL  HLA-B*55:01     B
# 170467    YKKEQTLK  HLA-B*55:01     B
# 170468  YLRMRRTAAL  HLA-B*15:10     B
# 170469    YVALDFEQ  HLA-C*08:03     C
#
# [170107 rows x 3 columns]
# Looking at dataset netmhc with total 170107 peptides across 109 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Australia_Cape_York_Peninsula_Aborigine_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia Cape York Peninsula Aborigine" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\netmhc_peptides.csv > iedb_afnd_pc_results\netmhc_Australia_Cape_York_Peninsula_Aborigine_real.txt
# iedb_afnd_pc_results\netmhc_Australia_Cape_York_Peninsula_Aborigine_real.txt
# ===============================
# Calculating PC for Australia Cape York Peninsula Aborigine for ideal dataset netmhc
# ===============================
# The original dataset netmhc has 170107 peptides
# The population has 46 alleles across 3 loci
# Ideal dataset has 170142 peptides across 46 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      13  A*01:01     A              3005
# 1      14  A*02:01     A              9922
# 2      15  A*03:01     A              2494
# 3      16  A*11:01     A             10206
# 4      17  A*24:02     A             12644
# 5      18  A*31:01     A               283
# 6      19  A*32:01     A              1077
# 7      20  A*33:03     A               283
# 8      21  A*34:01     A             16500
# 9      22  A*68:01     A               283
# 10  15124  B*07:02     B              2551
# 11  15125  B*08:01     B              1984
# 12  15126  B*13:01     B             15309
# 13  15127  B*14:01     B               283
# 14  15128  B*15:06     B               850
# 15  15129  B*15:21     B              7654
# 16  15130  B*18:01     B               567
# 17  15131  B*27:05     B               283
# 18  15132  B*35:01     B               283
# 19  15133  B*35:03     B               283
# 20  15134  B*38:01     B              1134
# 21  15135  B*39:01     B              1984
# 22  15136  B*40:01     B              4536
# 23  15137  B*40:02     B              4536
# 24  15138  B*44:02     B              1417
# 25  15139  B*48:01     B               283
# 26  15140  B*55:01     B               283
# 27  15141  B*56:01     B              9355
# 28  15142  B*56:02     B              1701
# 29  15143  B*57:01     B               850
# 30  15144  B*58:01     B               567
# 31  40292  C*01:02     C             10489
# 32  40293  C*02:02     C               340
# 33  40294  C*03:02     C               340
# 34  40295  C*03:03     C              1587
# 35  40296  C*03:04     C              1247
# 36  40297  C*04:01     C             15593
# 37  40298  C*04:03     C              8902
# 38  40299  C*05:01     C              1927
# 39  40300  C*06:02     C              1587
# 40  40301  C*07:01     C              1927
# 41  40302  C*07:02     C              5443
# 42  40303  C*07:04     C               340
# 43  40304  C*08:01     C               340
# 44  40305  C*12:03     C              2891
# 45  40306  C*15:02     C              3799
# Saved dummy ideal dataset to: iedb_afnd_pc_results\netmhc_Australia_Cape_York_Peninsula_Aborigine_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Australia_Cape_York_Peninsula_Aborigine_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.5216247553244959
# ===============================
# Calculating PC for Australia Cape York Peninsula Aborigine for dataset hlathena
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#              peptide       allele locus
# 0         AIDNSRNILY  HLA-A*01:01     A
# 1       AIGTYLDQYIVY  HLA-A*01:01     A
# 2          ALDDFTICY  HLA-A*01:01     A
# 3         ALDDFTICYF  HLA-A*01:01     A
# 4         ALDENGNLWY  HLA-A*01:01     A
# ...              ...          ...   ...
# 142295     YTSRIVVRL  HLA-C*17:01     C
# 142296     YVAPKAVWL  HLA-C*17:01     C
# 142297     YVAPRRILL  HLA-C*17:01     C
# 142298     YVVPYTIHL  HLA-C*17:01     C
# 142299     YVYKNVSQL  HLA-C*17:01     C
#
# [142300 rows x 3 columns]
# Looking at dataset hlathena with total 142300 peptides across 92 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Australia_Cape_York_Peninsula_Aborigine_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia Cape York Peninsula Aborigine" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\hlathena_peptides.csv > iedb_afnd_pc_results\hlathena_Australia_Cape_York_Peninsula_Aborigine_real.txt
# iedb_afnd_pc_results\hlathena_Australia_Cape_York_Peninsula_Aborigine_real.txt
# ===============================
# Calculating PC for Australia Cape York Peninsula Aborigine for ideal dataset hlathena
# ===============================
# The original dataset hlathena has 142300 peptides
# The population has 46 alleles across 3 loci
# Ideal dataset has 142331 peptides across 46 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      13  A*01:01     A              2513
# 1      14  A*02:01     A              8300
# 2      15  A*03:01     A              2087
# 3      16  A*11:01     A              8538
# 4      17  A*24:02     A             10577
# 5      18  A*31:01     A               237
# 6      19  A*32:01     A               901
# 7      20  A*33:03     A               237
# 8      21  A*34:01     A             13803
# 9      22  A*68:01     A               237
# 10  15124  B*07:02     B              2134
# 11  15125  B*08:01     B              1660
# 12  15126  B*13:01     B             12807
# 13  15127  B*14:01     B               237
# 14  15128  B*15:06     B               711
# 15  15129  B*15:21     B              6403
# 16  15130  B*18:01     B               474
# 17  15131  B*27:05     B               237
# 18  15132  B*35:01     B               237
# 19  15133  B*35:03     B               237
# 20  15134  B*38:01     B               948
# 21  15135  B*39:01     B              1660
# 22  15136  B*40:01     B              3794
# 23  15137  B*40:02     B              3794
# 24  15138  B*44:02     B              1185
# 25  15139  B*48:01     B               237
# 26  15140  B*55:01     B               237
# 27  15141  B*56:01     B              7826
# 28  15142  B*56:02     B              1423
# 29  15143  B*57:01     B               711
# 30  15144  B*58:01     B               474
# 31  40292  C*01:02     C              8775
# 32  40293  C*02:02     C               284
# 33  40294  C*03:02     C               284
# 34  40295  C*03:03     C              1328
# 35  40296  C*03:04     C              1043
# 36  40297  C*04:01     C             13044
# 37  40298  C*04:03     C              7447
# 38  40299  C*05:01     C              1612
# 39  40300  C*06:02     C              1328
# 40  40301  C*07:01     C              1612
# 41  40302  C*07:02     C              4553
# 42  40303  C*07:04     C               284
# 43  40304  C*08:01     C               284
# 44  40305  C*12:03     C              2419
# 45  40306  C*15:02     C              3178
# Saved dummy ideal dataset to: iedb_afnd_pc_results\hlathena_Australia_Cape_York_Peninsula_Aborigine_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Australia_Cape_York_Peninsula_Aborigine_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.6051816478218356
# ===============================
# Calculating PC for Australia Groote Eylandt Aborigine for dataset mhcflurry
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AADFPGIAR  HLA-A*01:01     A
# 1       AADKAAAAAY  HLA-A*01:01     A
# 2        AADKAAAAY  HLA-A*01:01     A
# 3        AADSFATSY  HLA-A*01:01     A
# 4       AAELDRTEEY  HLA-A*01:01     A
# ...            ...          ...   ...
# 187590   YVYFYDLSY  HLA-C*15:02     C
# 187591   YWMGGTTYF  HLA-C*15:02     C
# 187592   YYFSYPLFV  HLA-C*15:02     C
# 187593   YYGRWVHEF  HLA-C*15:02     C
# 187594   YYKKTFSAL  HLA-C*15:02     C
#
# [187485 rows x 3 columns]
# Looking at dataset mhcflurry with total 187485 peptides across 132 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Australia_Groote_Eylandt_Aborigine_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia Groote Eylandt Aborigine" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\mhcflurry_peptides.csv > iedb_afnd_pc_results\mhcflurry_Australia_Groote_Eylandt_Aborigine_real.txt
# iedb_afnd_pc_results\mhcflurry_Australia_Groote_Eylandt_Aborigine_real.txt
# ===============================
# Calculating PC for Australia Groote Eylandt Aborigine for ideal dataset mhcflurry
# ===============================
# The original dataset mhcflurry has 187485 peptides
# The population has 37 alleles across 3 loci
# Ideal dataset has 187718 peptides across 33 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      23  A*01:01     A              1687
# 1      24  A*02:01     A              6686
# 2      25  A*11:01     A             14998
# 3      26  A*24:02     A             18311
# 4      29  A*31:01     A               437
# 5      30  A*32:01     A               437
# 6      31  A*34:01     A             19998
# 7   15145  B*08:01     B              1249
# 8   15146  B*13:01     B             14561
# 9   15147  B*14:01     B               437
# 10  15148  B*15:02     B               437
# 11  15149  B*15:21     B              3749
# 12  15150  B*15:25     B              4999
# 13  15152  B*40:01     B             10811
# 14  15153  B*40:02     B             11249
# 15  15154  B*44:02     B               437
# 16  15155  B*44:03     B               437
# 17  15156  B*50:01     B               437
# 18  15157  B*51:01     B               437
# 19  15158  B*56:01     B             11249
# 20  15159  B*56:02     B              1687
# 21  15160  B*57:01     B               437
# 22  40307  C*01:02     C             16686
# 23  40308  C*03:03     C              9436
# 24  40309  C*03:04     C               437
# 25  40310  C*04:01     C             15811
# 26  40311  C*04:03     C              7686
# 27  40312  C*05:01     C               874
# 28  40313  C*06:02     C               874
# 29  40314  C*07:01     C              1312
# 30  40316  C*07:04     C               437
# 31  40317  C*08:02     C               437
# 32  40318  C*15:02     C              8561
# Saved dummy ideal dataset to: iedb_afnd_pc_results\mhcflurry_Australia_Groote_Eylandt_Aborigine_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Australia_Groote_Eylandt_Aborigine_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.5246218882159924
# ===============================
# Calculating PC for Australia Groote Eylandt Aborigine for dataset netmhc
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AAAAFEAAL  HLA-B*48:01     B
# 1        AAAAFEAAL  HLA-C*14:02     C
# 2        AAADFAHAE  HLA-B*44:03     B
# 3        AAAKTPVIV  HLA-A*02:01     A
# 4        AAAKTPVIV  HLA-A*68:02     A
# ...            ...          ...   ...
# 170465  YDGRYWTMWK  HLA-C*08:03     C
# 170466   YEPSQSAQL  HLA-B*55:01     B
# 170467    YKKEQTLK  HLA-B*55:01     B
# 170468  YLRMRRTAAL  HLA-B*15:10     B
# 170469    YVALDFEQ  HLA-C*08:03     C
#
# [170107 rows x 3 columns]
# Looking at dataset netmhc with total 170107 peptides across 109 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Australia_Groote_Eylandt_Aborigine_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia Groote Eylandt Aborigine" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\netmhc_peptides.csv > iedb_afnd_pc_results\netmhc_Australia_Groote_Eylandt_Aborigine_real.txt
# iedb_afnd_pc_results\netmhc_Australia_Groote_Eylandt_Aborigine_real.txt
# ===============================
# Calculating PC for Australia Groote Eylandt Aborigine for ideal dataset netmhc
# ===============================
# The original dataset netmhc has 170107 peptides
# The population has 37 alleles across 3 loci
# Ideal dataset has 170312 peptides across 33 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      23  A*01:01     A              1530
# 1      24  A*02:01     A              6067
# 2      25  A*11:01     A             13608
# 3      26  A*24:02     A             16613
# 4      29  A*31:01     A               396
# 5      30  A*32:01     A               396
# 6      31  A*34:01     A             18144
# 7   15145  B*08:01     B              1134
# 8   15146  B*13:01     B             13211
# 9   15147  B*14:01     B               396
# 10  15148  B*15:02     B               396
# 11  15149  B*15:21     B              3402
# 12  15150  B*15:25     B              4536
# 13  15152  B*40:01     B              9809
# 14  15153  B*40:02     B             10206
# 15  15154  B*44:02     B               396
# 16  15155  B*44:03     B               396
# 17  15156  B*50:01     B               396
# 18  15157  B*51:01     B               396
# 19  15158  B*56:01     B             10206
# 20  15159  B*56:02     B              1530
# 21  15160  B*57:01     B               396
# 22  40307  C*01:02     C             15139
# 23  40308  C*03:03     C              8562
# 24  40309  C*03:04     C               396
# 25  40310  C*04:01     C             14345
# 26  40311  C*04:03     C              6974
# 27  40312  C*05:01     C               793
# 28  40313  C*06:02     C               793
# 29  40314  C*07:01     C              1190
# 30  40316  C*07:04     C               396
# 31  40317  C*08:02     C               396
# 32  40318  C*15:02     C              7768
# Saved dummy ideal dataset to: iedb_afnd_pc_results\netmhc_Australia_Groote_Eylandt_Aborigine_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Australia_Groote_Eylandt_Aborigine_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.5816059645852134
# ===============================
# Calculating PC for Australia Groote Eylandt Aborigine for dataset hlathena
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#              peptide       allele locus
# 0         AIDNSRNILY  HLA-A*01:01     A
# 1       AIGTYLDQYIVY  HLA-A*01:01     A
# 2          ALDDFTICY  HLA-A*01:01     A
# 3         ALDDFTICYF  HLA-A*01:01     A
# 4         ALDENGNLWY  HLA-A*01:01     A
# ...              ...          ...   ...
# 142295     YTSRIVVRL  HLA-C*17:01     C
# 142296     YVAPKAVWL  HLA-C*17:01     C
# 142297     YVAPRRILL  HLA-C*17:01     C
# 142298     YVVPYTIHL  HLA-C*17:01     C
# 142299     YVYKNVSQL  HLA-C*17:01     C
#
# [142300 rows x 3 columns]
# Looking at dataset hlathena with total 142300 peptides across 92 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Australia_Groote_Eylandt_Aborigine_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia Groote Eylandt Aborigine" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\hlathena_peptides.csv > iedb_afnd_pc_results\hlathena_Australia_Groote_Eylandt_Aborigine_real.txt
# iedb_afnd_pc_results\hlathena_Australia_Groote_Eylandt_Aborigine_real.txt
# ===============================
# Calculating PC for Australia Groote Eylandt Aborigine for ideal dataset hlathena
# ===============================
# The original dataset hlathena has 142300 peptides
# The population has 37 alleles across 3 loci
# Ideal dataset has 142480 peptides across 33 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      23  A*01:01     A              1280
# 1      24  A*02:01     A              5075
# 2      25  A*11:01     A             11384
# 3      26  A*24:02     A             13897
# 4      29  A*31:01     A               332
# 5      30  A*32:01     A               332
# 6      31  A*34:01     A             15178
# 7   15145  B*08:01     B               948
# 8   15146  B*13:01     B             11051
# 9   15147  B*14:01     B               332
# 10  15148  B*15:02     B               332
# 11  15149  B*15:21     B              2846
# 12  15150  B*15:25     B              3794
# 13  15152  B*40:01     B              8205
# 14  15153  B*40:02     B              8538
# 15  15154  B*44:02     B               332
# 16  15155  B*44:03     B               332
# 17  15156  B*50:01     B               332
# 18  15157  B*51:01     B               332
# 19  15158  B*56:01     B              8538
# 20  15159  B*56:02     B              1280
# 21  15160  B*57:01     B               332
# 22  40307  C*01:02     C             12664
# 23  40308  C*03:03     C              7162
# 24  40309  C*03:04     C               332
# 25  40310  C*04:01     C             12000
# 26  40311  C*04:03     C              5834
# 27  40312  C*05:01     C               664
# 28  40313  C*06:02     C               664
# 29  40314  C*07:01     C               996
# 30  40316  C*07:04     C               332
# 31  40317  C*08:02     C               332
# 32  40318  C*15:02     C              6498
# Saved dummy ideal dataset to: iedb_afnd_pc_results\hlathena_Australia_Groote_Eylandt_Aborigine_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Australia_Groote_Eylandt_Aborigine_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.623864363738877
# ===============================
# Calculating PC for Australia Kimberly Aborigine for dataset mhcflurry
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AADFPGIAR  HLA-A*01:01     A
# 1       AADKAAAAAY  HLA-A*01:01     A
# 2        AADKAAAAY  HLA-A*01:01     A
# 3        AADSFATSY  HLA-A*01:01     A
# 4       AAELDRTEEY  HLA-A*01:01     A
# ...            ...          ...   ...
# 187590   YVYFYDLSY  HLA-C*15:02     C
# 187591   YWMGGTTYF  HLA-C*15:02     C
# 187592   YYFSYPLFV  HLA-C*15:02     C
# 187593   YYGRWVHEF  HLA-C*15:02     C
# 187594   YYKKTFSAL  HLA-C*15:02     C
#
# [187485 rows x 3 columns]
# Looking at dataset mhcflurry with total 187485 peptides across 132 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Australia_Kimberly_Aborigine_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia Kimberly Aborigine" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\mhcflurry_peptides.csv > iedb_afnd_pc_results\mhcflurry_Australia_Kimberly_Aborigine_real.txt
# iedb_afnd_pc_results\mhcflurry_Australia_Kimberly_Aborigine_real.txt
# ===============================
# Calculating PC for Australia Kimberly Aborigine for ideal dataset mhcflurry
# ===============================
# The original dataset mhcflurry has 187485 peptides
# The population has 18 alleles across 3 loci
# Ideal dataset has 187475 peptides across 18 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      32  A*02:01     A              6936
# 1      33  A*03:01     A               874
# 2      34  A*11:01     A              6062
# 3      35  A*24:02     A              5187
# 4      36  A*24:13     A               874
# 5      37  A*34:01     A             42559
# 6   15161  B*13:01     B              8249
# 7   15162  B*15:21     B              1624
# 8   15163  B*39:01     B               812
# 9   15164  B*40:01     B             11499
# 10  15165  B*40:02     B             17248
# 11  15166  B*56:01     B             22185
# 12  15167  B*56:02     B               812
# 13  40319  C*01:02     C             23435
# 14  40320  C*03:03     C              7811
# 15  40321  C*04:01     C             11186
# 16  40322  C*04:03     C              2249
# 17  40323  C*15:02     C             17873
# Saved dummy ideal dataset to: iedb_afnd_pc_results\mhcflurry_Australia_Kimberly_Aborigine_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Australia_Kimberly_Aborigine_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.6026832445450566
# ===============================
# Calculating PC for Australia Kimberly Aborigine for dataset netmhc
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AAAAFEAAL  HLA-B*48:01     B
# 1        AAAAFEAAL  HLA-C*14:02     C
# 2        AAADFAHAE  HLA-B*44:03     B
# 3        AAAKTPVIV  HLA-A*02:01     A
# 4        AAAKTPVIV  HLA-A*68:02     A
# ...            ...          ...   ...
# 170465  YDGRYWTMWK  HLA-C*08:03     C
# 170466   YEPSQSAQL  HLA-B*55:01     B
# 170467    YKKEQTLK  HLA-B*55:01     B
# 170468  YLRMRRTAAL  HLA-B*15:10     B
# 170469    YVALDFEQ  HLA-C*08:03     C
#
# [170107 rows x 3 columns]
# Looking at dataset netmhc with total 170107 peptides across 109 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Australia_Kimberly_Aborigine_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia Kimberly Aborigine" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\netmhc_peptides.csv > iedb_afnd_pc_results\netmhc_Australia_Kimberly_Aborigine_real.txt
# iedb_afnd_pc_results\netmhc_Australia_Kimberly_Aborigine_real.txt
# ===============================
# Calculating PC for Australia Kimberly Aborigine for ideal dataset netmhc
# ===============================
# The original dataset netmhc has 170107 peptides
# The population has 18 alleles across 3 loci
# Ideal dataset has 170098 peptides across 18 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      32  A*02:01     A              6293
# 1      33  A*03:01     A               793
# 2      34  A*11:01     A              5500
# 3      35  A*24:02     A              4706
# 4      36  A*24:13     A               793
# 5      37  A*34:01     A             38614
# 6   15161  B*13:01     B              7484
# 7   15162  B*15:21     B              1474
# 8   15163  B*39:01     B               737
# 9   15164  B*40:01     B             10433
# 10  15165  B*40:02     B             15649
# 11  15166  B*56:01     B             20129
# 12  15167  B*56:02     B               737
# 13  40319  C*01:02     C             21263
# 14  40320  C*03:03     C              7087
# 15  40321  C*04:01     C             10149
# 16  40322  C*04:03     C              2041
# 17  40323  C*15:02     C             16216
# Saved dummy ideal dataset to: iedb_afnd_pc_results\netmhc_Australia_Kimberly_Aborigine_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Australia_Kimberly_Aborigine_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.6483989394510149
# ===============================
# Calculating PC for Australia Kimberly Aborigine for dataset hlathena
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#              peptide       allele locus
# 0         AIDNSRNILY  HLA-A*01:01     A
# 1       AIGTYLDQYIVY  HLA-A*01:01     A
# 2          ALDDFTICY  HLA-A*01:01     A
# 3         ALDDFTICYF  HLA-A*01:01     A
# 4         ALDENGNLWY  HLA-A*01:01     A
# ...              ...          ...   ...
# 142295     YTSRIVVRL  HLA-C*17:01     C
# 142296     YVAPKAVWL  HLA-C*17:01     C
# 142297     YVAPRRILL  HLA-C*17:01     C
# 142298     YVVPYTIHL  HLA-C*17:01     C
# 142299     YVYKNVSQL  HLA-C*17:01     C
#
# [142300 rows x 3 columns]
# Looking at dataset hlathena with total 142300 peptides across 92 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Australia_Kimberly_Aborigine_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia Kimberly Aborigine" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\hlathena_peptides.csv > iedb_afnd_pc_results\hlathena_Australia_Kimberly_Aborigine_real.txt
# iedb_afnd_pc_results\hlathena_Australia_Kimberly_Aborigine_real.txt
# ===============================
# Calculating PC for Australia Kimberly Aborigine for ideal dataset hlathena
# ===============================
# The original dataset hlathena has 142300 peptides
# The population has 18 alleles across 3 loci
# Ideal dataset has 142292 peptides across 18 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      32  A*02:01     A              5265
# 1      33  A*03:01     A               664
# 2      34  A*11:01     A              4601
# 3      35  A*24:02     A              3936
# 4      36  A*24:13     A               664
# 5      37  A*34:01     A             32302
# 6   15161  B*13:01     B              6261
# 7   15162  B*15:21     B              1233
# 8   15163  B*39:01     B               616
# 9   15164  B*40:01     B              8727
# 10  15165  B*40:02     B             13091
# 11  15166  B*56:01     B             16838
# 12  15167  B*56:02     B               616
# 13  40319  C*01:02     C             17787
# 14  40320  C*03:03     C              5929
# 15  40321  C*04:01     C              8490
# 16  40322  C*04:03     C              1707
# 17  40323  C*15:02     C             13565
# Saved dummy ideal dataset to: iedb_afnd_pc_results\hlathena_Australia_Kimberly_Aborigine_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Australia_Kimberly_Aborigine_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.6761869090291375
# ===============================
# Calculating PC for Australia New South Wales Caucasian for dataset mhcflurry
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AADFPGIAR  HLA-A*01:01     A
# 1       AADKAAAAAY  HLA-A*01:01     A
# 2        AADKAAAAY  HLA-A*01:01     A
# 3        AADSFATSY  HLA-A*01:01     A
# 4       AAELDRTEEY  HLA-A*01:01     A
# ...            ...          ...   ...
# 187590   YVYFYDLSY  HLA-C*15:02     C
# 187591   YWMGGTTYF  HLA-C*15:02     C
# 187592   YYFSYPLFV  HLA-C*15:02     C
# 187593   YYGRWVHEF  HLA-C*15:02     C
# 187594   YYKKTFSAL  HLA-C*15:02     C
#
# [187485 rows x 3 columns]
# Looking at dataset mhcflurry with total 187485 peptides across 132 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Australia_New_South_Wales_Caucasian_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia New South Wales Caucasian" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\mhcflurry_peptides.csv > iedb_afnd_pc_results\mhcflurry_Australia_New_South_Wales_Caucasian_real.txt
# iedb_afnd_pc_results\mhcflurry_Australia_New_South_Wales_Caucasian_real.txt
# ===============================
# Calculating PC for Australia New South Wales Caucasian for ideal dataset mhcflurry
# ===============================
# The original dataset mhcflurry has 187485 peptides
# The population has 106 alleles across 3 loci
# Ideal dataset has 183809 peptides across 77 alleles
#     index   Allele Locus  ideal_n_peptides
# 0      38  A*01:01     A             11686
# 1      39  A*02:01     A             16311
# 2      41  A*02:05     A               499
# 3      43  A*02:07     A               499
# 4      44  A*03:01     A              8624
# ..    ...      ...   ...               ...
# 72  40338  C*14:02     C               624
# 73  40339  C*15:02     C               937
# 74  40340  C*15:05     C               312
# 75  40341  C*16:01     C              1249
# 76  40342  C*16:02     C               624
#
# [77 rows x 4 columns]
# Saved dummy ideal dataset to: iedb_afnd_pc_results\mhcflurry_Australia_New_South_Wales_Caucasian_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Australia_New_South_Wales_Caucasian_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.20666330221015328
# ===============================
# Calculating PC for Australia New South Wales Caucasian for dataset netmhc
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AAAAFEAAL  HLA-B*48:01     B
# 1        AAAAFEAAL  HLA-C*14:02     C
# 2        AAADFAHAE  HLA-B*44:03     B
# 3        AAAKTPVIV  HLA-A*02:01     A
# 4        AAAKTPVIV  HLA-A*68:02     A
# ...            ...          ...   ...
# 170465  YDGRYWTMWK  HLA-C*08:03     C
# 170466   YEPSQSAQL  HLA-B*55:01     B
# 170467    YKKEQTLK  HLA-B*55:01     B
# 170468  YLRMRRTAAL  HLA-B*15:10     B
# 170469    YVALDFEQ  HLA-C*08:03     C
#
# [170107 rows x 3 columns]
# Looking at dataset netmhc with total 170107 peptides across 109 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Australia_New_South_Wales_Caucasian_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Australia New South Wales Caucasian" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\netmhc_peptides.csv > iedb_afnd_pc_results\netmhc_Australia_New_South_Wales_Caucasian_real.txt
# iedb_afnd_pc_results\netmhc_Australia_New_South_Wales_Caucasian_real.txt
# ===============================
# Calculating PC for Australia New South Wales Caucasian for ideal dataset netmhc
# ===============================
# The original dataset netmhc has 170107 peptides
# The population has 106 alleles across 3 loci
# Ideal dataset has 166774 peptides across 77 alleles
# ...
# iedb_afnd_pc_results\hlathena_Vietnam_Kinh_real.txt
# ===============================
# Calculating PC for Vietnam Kinh for ideal dataset hlathena
# ===============================
# The original dataset hlathena has 142300 peptides
# The population has 85 alleles across 3 loci
# Ideal dataset has 141181 peptides across 85 alleles
#     index   Allele Locus  ideal_n_peptides
# 0   14996  A*01:01     A               706
# 1   14997  A*02:01     A              1408
# 2   14998  A*02:03     A              3524
# 3   14999  A*02:06     A              1408
# 4   15000  A*02:07     A              4695
# ..    ...      ...   ...               ...
# 80  50504  C*08:03     C               469
# 81  50505  C*12:02     C               706
# 82  50506  C*14:02     C               939
# 83  50507  C*15:02     C               706
# 84  50508  C*15:05     C              3287
#
# [85 rows x 4 columns]
# Saved dummy ideal dataset to: iedb_afnd_pc_results\hlathena_Vietnam_Kinh_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Vietnam_Kinh_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.5127701814412851
# ===============================
# Calculating PC for Zambia Lusaka for dataset mhcflurry
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AADFPGIAR  HLA-A*01:01     A
# 1       AADKAAAAAY  HLA-A*01:01     A
# 2        AADKAAAAY  HLA-A*01:01     A
# 3        AADSFATSY  HLA-A*01:01     A
# 4       AAELDRTEEY  HLA-A*01:01     A
# ...            ...          ...   ...
# 187590   YVYFYDLSY  HLA-C*15:02     C
# 187591   YWMGGTTYF  HLA-C*15:02     C
# 187592   YYFSYPLFV  HLA-C*15:02     C
# 187593   YYGRWVHEF  HLA-C*15:02     C
# 187594   YYKKTFSAL  HLA-C*15:02     C
#
# [187485 rows x 3 columns]
# Looking at dataset mhcflurry with total 187485 peptides across 132 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Zambia_Lusaka_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Zambia Lusaka" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\mhcflurry_peptides.csv > iedb_afnd_pc_results\mhcflurry_Zambia_Lusaka_real.txt
# iedb_afnd_pc_results\mhcflurry_Zambia_Lusaka_real.txt
# ===============================
# Calculating PC for Zambia Lusaka for ideal dataset mhcflurry
# ===============================
# The original dataset mhcflurry has 187485 peptides
# The population has 143 alleles across 3 loci
# Ideal dataset has 185579 peptides across 61 alleles
#     index   Allele Locus  ideal_n_peptides
# 0   15021  A*01:01     A              2187
# 1   15024  A*02:01     A              7999
# 2   15025  A*02:02     A              1437
# 3   15028  A*02:06     A               749
# 4   15030  A*02:14     A               749
# ..    ...      ...   ...               ...
# 56  50521  C*07:04     C              1374
# 57  50524  C*08:02     C              4187
# 58  50533  C*16:01     C              6249
# 59  50536  C*17:01     C              9749
# 60  50537  C*18:01     C              6249
#
# [61 rows x 4 columns]
# Saved dummy ideal dataset to: iedb_afnd_pc_results\mhcflurry_Zambia_Lusaka_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Zambia_Lusaka_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.27306616021440727
# ===============================
# Calculating PC for Zambia Lusaka for dataset netmhc
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AAAAFEAAL  HLA-B*48:01     B
# 1        AAAAFEAAL  HLA-C*14:02     C
# 2        AAADFAHAE  HLA-B*44:03     B
# 3        AAAKTPVIV  HLA-A*02:01     A
# 4        AAAKTPVIV  HLA-A*68:02     A
# ...            ...          ...   ...
# 170465  YDGRYWTMWK  HLA-C*08:03     C
# 170466   YEPSQSAQL  HLA-B*55:01     B
# 170467    YKKEQTLK  HLA-B*55:01     B
# 170468  YLRMRRTAAL  HLA-B*15:10     B
# 170469    YVALDFEQ  HLA-C*08:03     C
#
# [170107 rows x 3 columns]
# Looking at dataset netmhc with total 170107 peptides across 109 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Zambia_Lusaka_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Zambia Lusaka" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\netmhc_peptides.csv > iedb_afnd_pc_results\netmhc_Zambia_Lusaka_real.txt
# iedb_afnd_pc_results\netmhc_Zambia_Lusaka_real.txt
# ===============================
# Calculating PC for Zambia Lusaka for ideal dataset netmhc
# ===============================
# The original dataset netmhc has 170107 peptides
# The population has 143 alleles across 3 loci
# Ideal dataset has 168379 peptides across 61 alleles
#     index   Allele Locus  ideal_n_peptides
# 0   15021  A*01:01     A              1984
# 1   15024  A*02:01     A              7257
# 2   15025  A*02:02     A              1304
# 3   15028  A*02:06     A               680
# 4   15030  A*02:14     A               680
# ..    ...      ...   ...               ...
# 56  50521  C*07:04     C              1247
# 57  50524  C*08:02     C              3799
# 58  50533  C*16:01     C              5670
# 59  50536  C*17:01     C              8845
# 60  50537  C*18:01     C              5670
#
# [61 rows x 4 columns]
# Saved dummy ideal dataset to: iedb_afnd_pc_results\netmhc_Zambia_Lusaka_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Zambia_Lusaka_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.3778383101010776
# ===============================
# Calculating PC for Zambia Lusaka for dataset hlathena
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#              peptide       allele locus
# 0         AIDNSRNILY  HLA-A*01:01     A
# 1       AIGTYLDQYIVY  HLA-A*01:01     A
# 2          ALDDFTICY  HLA-A*01:01     A
# 3         ALDDFTICYF  HLA-A*01:01     A
# 4         ALDENGNLWY  HLA-A*01:01     A
# ...              ...          ...   ...
# 142295     YTSRIVVRL  HLA-C*17:01     C
# 142296     YVAPKAVWL  HLA-C*17:01     C
# 142297     YVAPRRILL  HLA-C*17:01     C
# 142298     YVVPYTIHL  HLA-C*17:01     C
# 142299     YVYKNVSQL  HLA-C*17:01     C
#
# [142300 rows x 3 columns]
# Looking at dataset hlathena with total 142300 peptides across 92 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Zambia_Lusaka_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Zambia Lusaka" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\hlathena_peptides.csv > iedb_afnd_pc_results\hlathena_Zambia_Lusaka_real.txt
# iedb_afnd_pc_results\hlathena_Zambia_Lusaka_real.txt
# ===============================
# Calculating PC for Zambia Lusaka for ideal dataset hlathena
# ===============================
# The original dataset hlathena has 142300 peptides
# The population has 143 alleles across 3 loci
# Ideal dataset has 140842 peptides across 61 alleles
#     index   Allele Locus  ideal_n_peptides
# 0   15021  A*01:01     A              1660
# 1   15024  A*02:01     A              6071
# 2   15025  A*02:02     A              1090
# 3   15028  A*02:06     A               569
# 4   15030  A*02:14     A               569
# ..    ...      ...   ...               ...
# 56  50521  C*07:04     C              1043
# 57  50524  C*08:02     C              3178
# 58  50533  C*16:01     C              4743
# 59  50536  C*17:01     C              7399
# 60  50537  C*18:01     C              4743
#
# [61 rows x 4 columns]
# Saved dummy ideal dataset to: iedb_afnd_pc_results\hlathena_Zambia_Lusaka_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Zambia_Lusaka_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.4921981890842291
# ===============================
# Calculating PC for Zimbabwe Harare Shona for dataset mhcflurry
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AADFPGIAR  HLA-A*01:01     A
# 1       AADKAAAAAY  HLA-A*01:01     A
# 2        AADKAAAAY  HLA-A*01:01     A
# 3        AADSFATSY  HLA-A*01:01     A
# 4       AAELDRTEEY  HLA-A*01:01     A
# ...            ...          ...   ...
# 187590   YVYFYDLSY  HLA-C*15:02     C
# 187591   YWMGGTTYF  HLA-C*15:02     C
# 187592   YYFSYPLFV  HLA-C*15:02     C
# 187593   YYGRWVHEF  HLA-C*15:02     C
# 187594   YYKKTFSAL  HLA-C*15:02     C
#
# [187485 rows x 3 columns]
# Looking at dataset mhcflurry with total 187485 peptides across 132 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Zimbabwe_Harare_Shona_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Zimbabwe Harare Shona" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\mhcflurry_peptides.csv > iedb_afnd_pc_results\mhcflurry_Zimbabwe_Harare_Shona_real.txt
# iedb_afnd_pc_results\mhcflurry_Zimbabwe_Harare_Shona_real.txt
# ===============================
# Calculating PC for Zimbabwe Harare Shona for ideal dataset mhcflurry
# ===============================
# The original dataset mhcflurry has 187485 peptides
# The population has 91 alleles across 3 loci
# Ideal dataset has 184423 peptides across 91 alleles
#     index   Allele Locus  ideal_n_peptides
# 0   15069  A*01:01     A               249
# 1   15070  A*02:01     A              5687
# 2   15071  A*02:02     A              2249
# 3   15072  A*02:05     A              1937
# 4   15073  A*02:17     A               124
# ..    ...      ...   ...               ...
# 86  50555  C*14:03     C               249
# 87  50556  C*15:05     C               124
# 88  50557  C*16:01     C              4999
# 89  50558  C*17:01     C              5124
# 90  50559  C*18:01     C              3062
#
# [91 rows x 4 columns]
# Saved dummy ideal dataset to: iedb_afnd_pc_results\mhcflurry_Zimbabwe_Harare_Shona_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\mhcflurry_Zimbabwe_Harare_Shona_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.22957529660049028
# ===============================
# Calculating PC for Zimbabwe Harare Shona for dataset netmhc
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#            peptide       allele locus
# 0        AAAAFEAAL  HLA-B*48:01     B
# 1        AAAAFEAAL  HLA-C*14:02     C
# 2        AAADFAHAE  HLA-B*44:03     B
# 3        AAAKTPVIV  HLA-A*02:01     A
# 4        AAAKTPVIV  HLA-A*68:02     A
# ...            ...          ...   ...
# 170465  YDGRYWTMWK  HLA-C*08:03     C
# 170466   YEPSQSAQL  HLA-B*55:01     B
# 170467    YKKEQTLK  HLA-B*55:01     B
# 170468  YLRMRRTAAL  HLA-B*15:10     B
# 170469    YVALDFEQ  HLA-C*08:03     C
#
# [170107 rows x 3 columns]
# Looking at dataset netmhc with total 170107 peptides across 109 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Zimbabwe_Harare_Shona_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Zimbabwe Harare Shona" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\netmhc_peptides.csv > iedb_afnd_pc_results\netmhc_Zimbabwe_Harare_Shona_real.txt
# iedb_afnd_pc_results\netmhc_Zimbabwe_Harare_Shona_real.txt
# ===============================
# Calculating PC for Zimbabwe Harare Shona for ideal dataset netmhc
# ===============================
# The original dataset netmhc has 170107 peptides
# The population has 91 alleles across 3 loci
# Ideal dataset has 167335 peptides across 91 alleles
#     index   Allele Locus  ideal_n_peptides
# 0   15069  A*01:01     A               226
# 1   15070  A*02:01     A              5159
# 2   15071  A*02:02     A              2041
# 3   15072  A*02:05     A              1757
# 4   15073  A*02:17     A               113
# ..    ...      ...   ...               ...
# 86  50555  C*14:03     C               226
# 87  50556  C*15:05     C               113
# 88  50557  C*16:01     C              4536
# 89  50558  C*17:01     C              4649
# 90  50559  C*18:01     C              2778
#
# [91 rows x 4 columns]
# Saved dummy ideal dataset to: iedb_afnd_pc_results\netmhc_Zimbabwe_Harare_Shona_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\netmhc_Zimbabwe_Harare_Shona_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.3365145199485812
# ===============================
# Calculating PC for Zimbabwe Harare Shona for dataset hlathena
# ===============================
# Saving outputs to: iedb_afnd_pc_results
#              peptide       allele locus
# 0         AIDNSRNILY  HLA-A*01:01     A
# 1       AIGTYLDQYIVY  HLA-A*01:01     A
# 2          ALDDFTICY  HLA-A*01:01     A
# 3         ALDDFTICYF  HLA-A*01:01     A
# 4         ALDENGNLWY  HLA-A*01:01     A
# ...              ...          ...   ...
# 142295     YTSRIVVRL  HLA-C*17:01     C
# 142296     YVAPKAVWL  HLA-C*17:01     C
# 142297     YVAPRRILL  HLA-C*17:01     C
# 142298     YVVPYTIHL  HLA-C*17:01     C
# 142299     YVYKNVSQL  HLA-C*17:01     C
#
# [142300 rows x 3 columns]
# Looking at dataset hlathena with total 142300 peptides across 92 alleles 3 loci
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Zimbabwe_Harare_Shona_real.txt
# python IEDB_Population_Coverage-3.0.2\population_coverage\calculate_population_coverage.py -p "Zimbabwe Harare Shona" -c I -f C:\Users\ac121\Documents\HLAequity\HLAlleleBias\Datasets_coverage\datasets\hlathena_peptides.csv > iedb_afnd_pc_results\hlathena_Zimbabwe_Harare_Shona_real.txt
# iedb_afnd_pc_results\hlathena_Zimbabwe_Harare_Shona_real.txt
# ===============================
# Calculating PC for Zimbabwe Harare Shona for ideal dataset hlathena
# ===============================
# The original dataset hlathena has 142300 peptides
# The population has 91 alleles across 3 loci
# Ideal dataset has 139967 peptides across 91 alleles
#     index   Allele Locus  ideal_n_peptides
# 0   15069  A*01:01     A               189
# 1   15070  A*02:01     A              4316
# 2   15071  A*02:02     A              1707
# 3   15072  A*02:05     A              1470
# 4   15073  A*02:17     A                94
# ..    ...      ...   ...               ...
# 86  50555  C*14:03     C               189
# 87  50556  C*15:05     C                94
# 88  50557  C*16:01     C              3794
# 89  50558  C*17:01     C              3889
# 90  50559  C*18:01     C              2324
#
# [91 rows x 4 columns]
# Saved dummy ideal dataset to: iedb_afnd_pc_results\hlathena_Zimbabwe_Harare_Shona_ideal.csv
# Running IEDB tool for population coverage and saving output to: iedb_afnd_pc_results\hlathena_Zimbabwe_Harare_Shona_ideal.txt
# ===============================
# Plotting results
# ===============================
# ===============================
# Calculating JS divergence
# ===============================
# JS divergence: 0.43749517177821573
