# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os

# %% [markdown]
# # 1 - Visualize per-allele dataset contents

# %%
# datasets
data_fname = "./datasets/{}_peptides_ms_all.csv"
all_datasets = ["mhcflurry", "netmhc"]
all_datasets_names = ["MHCFlurry2.0", "NetMHCpan4.1", "MHCFlurry2.0", "NetMHCpan4.1"]
all_datasets_fname = [data_fname.format(x) for x in all_datasets]

# %%
data_fname = "./datasets/{}_peptides_ba.csv"
all_datasets_fname.extend([data_fname.format(x) for x in all_datasets])

# %%
all_data_pd = None
for i, ds in enumerate(all_datasets_fname):
    dataset_df =  pd.read_csv(ds, header=None, sep="\t")
    if "_ba" in ds:
        dataset_df["dataset_name"] = dataset_df[0].apply(lambda x: all_datasets_names[i]+"_BA")
    if "_ms_" in ds:
        dataset_df["dataset_name"] = dataset_df[0].apply(lambda x: all_datasets_names[i]+"_MS")
        
    if all_data_pd is None:
        all_data_pd = dataset_df
    else:
        all_data_pd = pd.concat([all_data_pd, dataset_df])

# %%
all_data_pd.columns = ["peptide", "allele", "locus", "dataset_name"]
all_data_pd
# Out:
#             peptide       allele locus     dataset_name
# 0        RYMPQNPCII  HLA-A*24:02     A  MHCFlurry2.0_MS
# 1         LYQGLLPSL  HLA-A*24:02     A  MHCFlurry2.0_MS
# 2       YYNPHLLLNTL  HLA-A*24:02     A  MHCFlurry2.0_MS
# 3         KTNHVFFLL  HLA-A*24:02     A  MHCFlurry2.0_MS
# 4         TYRNVMEQF  HLA-A*24:02     A  MHCFlurry2.0_MS
# ...             ...          ...   ...              ...
# 170465   YDGRYWTMWK  HLA-C*08:03     C  NetMHCpan4.1_BA
# 170466    YEPSQSAQL  HLA-B*55:01     B  NetMHCpan4.1_BA
# 170467     YKKEQTLK  HLA-B*55:01     B  NetMHCpan4.1_BA
# 170468   YLRMRRTAAL  HLA-B*15:10     B  NetMHCpan4.1_BA
# 170469     YVALDFEQ  HLA-C*08:03     C  NetMHCpan4.1_BA
#
# [1182894 rows x 4 columns]

# %%
all_data_freqs = all_data_pd.groupby(by=["dataset_name", "allele"]).count().groupby(["dataset_name"]).apply(lambda x: x*100/x.sum())

# %%
all_data_freqs
# Out:
#                                               peptide     locus
# dataset_name    dataset_name    allele
# MHCFlurry2.0_BA MHCFlurry2.0_BA HLA-A*01:01  3.063406  3.063406
#                                 HLA-A*02:01  9.496377  9.496377
#                                 HLA-A*02:02  2.528986  2.528986
#                                 HLA-A*02:03  3.824275  3.824275
#                                 HLA-A*02:04  0.005435  0.005435
# ...                                               ...       ...
# NetMHCpan4.1_MS NetMHCpan4.1_MS HLA-C*15:02  0.575444  0.575444
#                                 HLA-C*15:05  0.032119  0.032119
#                                 HLA-C*16:01  1.274862  1.274862
#                                 HLA-C*16:04  0.017410  0.017410
#                                 HLA-C*17:01  0.180708  0.180708
#
# [540 rows x 2 columns]

# %%
all_data_counts = all_data_pd.groupby(by=["dataset_name", "allele"]).count().reset_index()

# %%
all_data_freqs = all_data_freqs.sort_values(["dataset_name", "allele"], ascending=[False, True])

# %%
all_data_counts = all_data_counts.sort_values(["dataset_name", "allele"], ascending=[False, True])
all_data_counts["allele_short"] = all_data_counts["allele"].apply(lambda x: x[4:])

# %%
all_data_freqs["allele_short"] = all_data_freqs["allele"].apply(lambda x: x[4:])

# %%
#all_data["proc"] = all_data["freq"].apply(lambda x: x*100)
fig_A = px.scatter(all_data_freqs[all_data_freqs.apply(lambda x: x.allele[4]=="A" and x.peptide > 0.1, axis=1)]\
             , x="allele_short", y="peptide", color='dataset_name', width=1500, height=300)
fig_A.update_xaxes(title="<b>HLA Allele</b>", titlefont = dict(size = 18), tickfont = dict(size = 15), tickangle = 45)
fig_A.update_yaxes(title="<b>percent within the dataset</b>", titlefont = dict(size = 18), tickfont = dict(size = 15))
#fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="black")
fig_A.show()
# Out:
# <div>                            <div id="08cd86b2-1145-420c-9be6-16622ce75a6e" class="plotly-graph-div" style="height:300px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08cd86b2-1145-420c-9be6-16622ce75a6e")) {                    Plotly.newPlot(                        "08cd86b2-1145-420c-9be6-16622ce75a6e",                        [{"hovertemplate":"dataset_name=NetMHCpan4.1_MS<br>allele_short=%{x}<br>peptide=%{y}<extra></extra>","legendgroup":"NetMHCpan4.1_MS","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"NetMHCpan4.1_MS","orientation":"v","showlegend":true,"type":"scatter","x":["A*01:01","A*02:01","A*02:03","A*02:04","A*02:05","A*02:06","A*02:07","A*02:20","A*03:01","A*03:02","A*11:01","A*23:01","A*24:02","A*24:06","A*25:01","A*26:01","A*29:02","A*30:01","A*31:01","A*32:01","A*68:01","A*68:02"],"xaxis":"x","y":[3.1746984696848717,6.001188710849088,0.6207712211902718,0.9470663456747135,0.5424243697731244,0.13388006027604507,1.2127252096753858,0.3079841745363727,4.744036934086584,0.33560068921214886,1.4135453000894536,0.5595346016918117,2.318586514735812,0.10686390461495975,0.4655784158927038,0.5256143173617823,2.2843660508984374,0.36501828093199734,1.085749278068285,0.2947762762131755,3.352404738033344,0.7750634879658036],"yaxis":"y"},{"hovertemplate":"dataset_name=NetMHCpan4.1_BA<br>allele_short=%{x}<br>peptide=%{y}<extra></extra>","legendgroup":"NetMHCpan4.1_BA","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"NetMHCpan4.1_BA","orientation":"v","showlegend":true,"type":"scatter","x":["A*01:01","A*02:01","A*02:02","A*02:03","A*02:05","A*02:06","A*02:07","A*02:11","A*02:12","A*02:16","A*02:17","A*02:19","A*02:50","A*03:01","A*11:01","A*23:01","A*24:02","A*24:03","A*25:01","A*26:01","A*26:02","A*26:03","A*29:02","A*30:01","A*30:02","A*31:01","A*32:01","A*32:07","A*32:15","A*33:01","A*66:01","A*68:01","A*68:02","A*68:23","A*69:01","A*80:01"],"xaxis":"x","y":[2.923094972722473,7.598404411333372,2.509532469056139,3.767818384466475,0.12964157916348917,3.3736141256526073,0.10617703994837802,0.6945503607672905,0.7520384818443128,0.5989323634657124,0.26162961224848946,0.7895817445884906,0.13785416788877808,4.447116794743943,3.858743473925031,1.6026280283920924,2.031442482548249,0.8687745644394909,0.6218102892004458,2.718953481551006,0.43585381592068984,0.3742594004810231,1.694139731331026,1.7750923916231596,1.293482724233003,3.4058778670733854,0.7221211943450461,0.10969672083064469,0.10207074558573356,2.164017129113627,0.18771631372088932,2.302457910482783,3.3319645685457853,0.1067636534287558,1.566844606089048,0.7467589605209127],"yaxis":"y"},{"hovertemplate":"dataset_name=MHCFlurry2.0_MS<br>allele_short=%{x}<br>peptide=%{y}<extra></extra>","legendgroup":"MHCFlurry2.0_MS","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"MHCFlurry2.0_MS","orientation":"v","showlegend":true,"type":"scatter","x":["A*01:01","A*02:01","A*02:02","A*02:03","A*02:04","A*02:05","A*02:06","A*02:07","A*02:11","A*02:20","A*03:01","A*11:01","A*11:02","A*23:01","A*24:02","A*24:07","A*25:01","A*26:01","A*29:02","A*30:01","A*30:02","A*31:01","A*32:01","A*33:01","A*33:03","A*34:01","A*34:02","A*36:01","A*66:01","A*68:01","A*68:02","A*74:01"],"xaxis":"x","y":[1.8703887558644319,4.174696801572933,0.6667445346415153,0.5501372423056707,0.6842648289824602,0.7084039011855399,0.48628550292978256,0.9200101228367303,0.4286632015417859,0.18415776051704336,2.96423913255076,1.584029278358543,0.561038758784481,0.729817594268917,1.4933130876598726,0.2830500885748214,0.4097802176409897,0.5184060425548482,1.531079055461465,0.4784987054449181,0.5437131343806576,0.7039264926317429,0.6237224785376394,0.4860908329926609,0.5923806186610602,0.4594210516070003,0.7249508458408768,0.5088672156358893,0.42768985185617786,2.071 ...

# %%
import plotly.graph_objects as go

# %%
import plotly.express as px

print(px.colors.qualitative.Vivid)
# Out:
# ['rgb(229, 134, 6)', 'rgb(93, 105, 177)', 'rgb(82, 188, 163)', 'rgb(153, 201, 69)', 'rgb(204, 97, 176)', 'rgb(36, 121, 108)', 'rgb(218, 165, 27)', 'rgb(47, 138, 196)', 'rgb(118, 78, 159)', 'rgb(237, 100, 90)', 'rgb(165, 170, 153)']

# %%
# Out:
#         dataset_name       allele  peptide  locus allele_short
# 396  NetMHCpan4.1_MS  HLA-A*01:01    10576  10576      A*01:01
# 398  NetMHCpan4.1_MS  HLA-A*02:01    19992  19992      A*02:01
# 399  NetMHCpan4.1_MS  HLA-A*02:03     2068   2068      A*02:03
# 400  NetMHCpan4.1_MS  HLA-A*02:04     3155   3155      A*02:04
# 401  NetMHCpan4.1_MS  HLA-A*02:05     1807   1807      A*02:05
# ..               ...          ...      ...    ...          ...
# 125  MHCFlurry2.0_BA  HLA-C*08:02      135    135      C*08:02
# 127  MHCFlurry2.0_BA  HLA-C*12:02       27     27      C*12:02
# 128  MHCFlurry2.0_BA  HLA-C*12:03      172    172      C*12:03
# 129  MHCFlurry2.0_BA  HLA-C*14:02      243    243      C*14:02
# 130  MHCFlurry2.0_BA  HLA-C*15:02      181    181      C*15:02
#
# [365 rows x 5 columns]

# %%
interesting_alleles = all_data_counts[all_data_counts.allele\
                                      .apply(lambda x: any(all_data_counts[all_data_counts.allele==x].peptide > 1000))]\
.allele.unique()
all_alleles_all_datasets = pd.DataFrame({"dataset_name": all_data_counts.dataset_name.unique()}).merge( \
pd.DataFrame({"allele": interesting_alleles}) ,\
         how="cross")
def get_counts(allele, dataset_name, all_data_counts):
    tmp = all_data_counts[(all_data_counts.allele == allele)\
                    & (all_data_counts.dataset_name == dataset_name)].peptide
    if tmp.shape[0]>0:
        return tmp.iloc[0]
    else:
        return 0
                                                                          
all_alleles_all_datasets["peptide_counts"] = all_alleles_all_datasets.apply(lambda x: \
                                                                            get_counts(x.allele, x.dataset_name, \
                                                                                      all_data_counts), axis=1)

# %%
all_alleles_all_datasets["allele_short"] = all_alleles_all_datasets["allele"].apply(lambda x: x[4:])

# %%
tmp_data
# Out:
#         dataset_name       allele  peptide_counts allele_short  symbols  \
# 120  NetMHCpan4.1_MS  HLA-C*01:02            1700      C*01:02  line-ew
# 121  NetMHCpan4.1_MS  HLA-C*02:02            2733      C*02:02  line-ew
# 122  NetMHCpan4.1_MS  HLA-C*02:10              34      C*02:10  line-ew
# 123  NetMHCpan4.1_MS  HLA-C*03:03            2961      C*03:03  line-ew
# 124  NetMHCpan4.1_MS  HLA-C*03:04            2893      C*03:04  line-ew
# ..               ...          ...             ...          ...      ...
# 763  MHCFlurry2.0_BA  HLA-C*03:01               0      C*03:01  line-ne
# 764  MHCFlurry2.0_BA  HLA-C*03:02               0      C*03:02  line-ne
# 765  MHCFlurry2.0_BA  HLA-C*03:13               0      C*03:13  line-ne
# 766  MHCFlurry2.0_BA  HLA-C*04:03               0      C*04:03  line-ne
# 767  MHCFlurry2.0_BA  HLA-C*14:03               0      C*14:03  line-ne
#
#                color  allele_order
# 120  rgb(55,126,184)            15
# 121  rgb(55,126,184)            12
# 122  rgb(55,126,184)            24
# 123  rgb(55,126,184)             4
# 124  rgb(55,126,184)             9
# ..               ...           ...
# 763   rgb(228,26,28)            22
# 764   rgb(228,26,28)            18
# 765   rgb(228,26,28)            25
# 766   rgb(228,26,28)            19
# 767   rgb(228,26,28)            14
#
# [116 rows x 7 columns]

# %%
def plot(all_alleles_all_datasets, locus):
    tmp_data = all_alleles_all_datasets[all_alleles_all_datasets.apply(lambda x: x.allele[4]==locus, axis=1)]
    symbols_dict = {"MHCFlurry2.0_BA": "line-ne", \
                    "NetMHCpan4.1_BA": "line-nw", \
                    "MHCFlurry2.0_MS": "line-ns", \
                    "NetMHCpan4.1_MS": "line-ew" }
    colors_dict = {"MHCFlurry2.0_BA": px.colors.qualitative.D3[3], \
                    "NetMHCpan4.1_BA": px.colors.qualitative.D3[3], \
                    "MHCFlurry2.0_MS": px.colors.qualitative.D3[0], \
                    "NetMHCpan4.1_MS": px.colors.qualitative.D3[0]}
    allele_order_df = tmp_data[tmp_data["dataset_name"]=="MHCFlurry2.0_MS"][["allele", "peptide_counts"]]\
    .sort_values(by="peptide_counts", ascending=False).reset_index(drop=True).reset_index()[["allele", "index"]]
    tmp_data["symbols"] = tmp_data.dataset_name.apply(lambda x: symbols_dict[x])
    tmp_data["color"] = tmp_data.dataset_name.apply(lambda x: colors_dict[x])
    tmp_data["allele_order"] = tmp_data.allele.apply(lambda x: allele_order_df["index"][allele_order_df.allele==x].iloc[0])
    #tmp_data = tmp_data.sort_values(by=["peptide_counts", "allele_short"], ascending=[False, True])
    fig = go.Figure()
    for dsn in ["MHCFlurry2.0_MS", "NetMHCpan4.1_MS", "MHCFlurry2.0_BA", "NetMHCpan4.1_BA"]:
        tmp_data_ds = tmp_data[tmp_data.dataset_name == dsn].sort_values(by="allele_order")
        tmp_data_ds_no_zeros = tmp_data_ds[tmp_data_ds["peptide_counts"]!=0]
        #tmp_data_ds = tmp_data_ds.sort_values(by="allele_short")
        '''
        fig.add_trace(go.Bar(x=tmp_data_ds.allele_short, y=tmp_data_ds.peptide_counts,#/tmp_data_ds.peptide_counts.sum(), \
                             name = dsn, marker_color = colors_dict[dsn]\
                            # marker_symbol=tmp_data_ds.symbols, opacity=0.5, \
                             #marker_line_width=1, marker_size=0, marker_color = tmp_data_ds.color,\
                             #line_color = colors_dict[dsn], line=dict(dash='dot')
                          ))
        '''
        fig.add_trace(go.Scatter(mode="lines", x=tmp_data_ds.allele_short, y=tmp_data_ds.peptide_counts, \
                                 marker_symbol=tmp_data_ds.symbols, opacity=0.5, \
                                 marker_line_width=1, marker_size=0, name = dsn, marker_color = tmp_data_ds.color,\
                                 line_color = colors_dict[dsn], line=dict(dash='dot')
                              ))

        fig.add_trace(go.Scatter(mode="markers", x=tmp_data_ds_no_zeros.allele_short, y=tmp_data_ds_no_zeros.peptide_counts, \
                             marker_symbol=tmp_data_ds_no_zeros.symbols, opacity=1, \
                             marker_line_width=2, marker_size=9, name = dsn, marker_color = tmp_data_ds_no_zeros.color,\
                             line_color = colors_dict[dsn], line=dict(dash='dot')
                          ))
        fig.add_trace(go.Scatter(mode="markers", x=tmp_data_ds_no_zeros.allele_short, y=tmp_data_ds_no_zeros.peptide_counts, \
                         marker_symbol="circle-open", opacity=1, \
                         marker_line_width=2, marker_size=9, name = dsn, marker_color = tmp_data_ds_no_zeros.color,\
                         line_color = colors_dict[dsn], line=dict(dash='dot')
                      ))
        
                              # marker_line_width=2, marker_size=15,
                              # hovertemplate="name: %{y}%{x}<br>number: %{marker.symbol}<extra></extra>"))
    fig.update_layout(width=800, height=400, yaxis_range=[-1000, 25000], \
                      #barmode='stack',\
                      xaxis=dict(tickangle=45,tick0=0, dtick=1.2))
    return fig

# %%
fig = plot(all_alleles_all_datasets, "C")
# Out:
# <ipython-input-670-b244fa00b8cd>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-670-b244fa00b8cd>:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-670-b244fa00b8cd>:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig
# Out:
# <div>                            <div id="df09a4c8-859e-4c07-ac7d-ab03b4cf5f91" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df09a4c8-859e-4c07-ac7d-ab03b4cf5f91")) {                    Plotly.newPlot(                        "df09a4c8-859e-4c07-ac7d-ab03b4cf5f91",                        [{"line":{"color":"#1F77B4","dash":"dot"},"marker":{"color":["#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4"],"line":{"width":1},"size":0,"symbol":["line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns"]},"mode":"lines","name":"MHCFlurry2.0_MS","opacity":0.5,"type":"scatter","x":["C*12:02","C*05:01","C*16:01","C*08:02","C*03:03","C*06:02","C*15:02","C*07:01","C*12:03","C*03:04","C*07:02","C*14:02","C*02:02","C*04:01","C*14:03","C*01:02","C*08:01","C*17:01","C*03:02","C*04:03"],"y":[11168,6010,5702,5253,4755,4555,4338,4334,4199,4116,3640,3534,3353,3279,2986,2523,1925,1468,1277,1133]},{"line":{"color":"#1F77B4","dash":"dot"},"marker":{"color":["#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4"],"line":{"width":2},"size":9,"symbol":["line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns"]},"mode":"markers","name":"MHCFlurry2.0_MS","opacity":1,"type":"scatter","x":["C*12:02","C*05:01","C*16:01","C*08:02","C*03:03","C*06:02","C*15:02","C*07:01","C*12:03","C*03:04","C*07:02","C*14:02","C*02:02","C*04:01","C*14:03","C*01:02","C*08:01","C*17:01","C*03:02","C*04:03"],"y":[11168,6010,5702,5253,4755,4555,4338,4334,4199,4116,3640,3534,3353,3279,2986,2523,1925,1468,1277,1133]},{"line":{"color":"#1F77B4","dash":"dot"},"marker":{"color":["#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4"],"line":{"width":2},"size":9,"symbol":"circle-open"},"mode":"markers","name":"MHCFlurry2.0_MS","opacity":1,"type":"scatter","x":["C*12:02","C*05:01","C*16:01","C*08:02","C*03:03","C*06:02","C*15:02","C*07:01","C*12:03","C*03:04","C*07:02","C*14:02","C*02:02","C*04:01","C*14:03","C*01:02","C*08:01","C*17:01","C*03:02","C*04:03"],"y":[11168,6010,5702,5253,4755,4555,4338,4334,4199,4116,3640,3534,3353,3279,2986,2523,1925,1468,1277,1133]},{"line":{"color":"#1F77B4","dash":"dot"},"marker":{"color":["#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4"],"line":{"width":1},"size":0,"symbol":["line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew"]},"mode":"lines","name":"NetMHCpan4.1_MS","opacity":0.5,"type":"scatter","x":["C*12:02","C*05:01","C*16:01","C*08:02","C*03:03","C*06:02","C*15:02","C*07:01","C*12:03","C*03:04","C*07:02","C*14:02","C*02:02","C*04:01","C*14:03","C*01:02","C*08:01","C*17:01","C*03:02","C*04:03"],"y":[730,5943,4247,3647,2961,3037,1917,1462,3349,2893,3190,2942,2733,2795,0,1700,101,602,0,0]},{"line":{"color":"#1F77B4","dash":"dot"},"marker":{"color":["#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F77B4","#1F7 ...

# %%
fig.write_image("scatterplot_C_alleles.svg", width=800, height=400)

# %%
plot(all_alleles_all_datasets, "B")
# Out:
# <ipython-input-654-98c46b5dd6a6>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-654-98c46b5dd6a6>:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-654-98c46b5dd6a6>:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="efbfa400-538e-4923-912b-5f23ce5fea0c" class="plotly-graph-div" style="height:400px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efbfa400-538e-4923-912b-5f23ce5fea0c")) {                    Plotly.newPlot(                        "efbfa400-538e-4923-912b-5f23ce5fea0c",                        [{"line":{"color":"#636EFA","dash":"dot"},"marker":{"color":["#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA"],"line":{"width":1},"size":0,"symbol":["line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns"]},"mode":"lines","name":"MHCFlurry2.0_MS","opacity":0.5,"type":"scatter","x":["B*27:05","B*57:01","B*07:02","B*40:02","B*15:01","B*44:02","B*44:03","B*08:01","B*40:01","B*57:03","B*27:09","B*51:01","B*58:01","B*35:01","B*38:01","B*18:01","B*35:03","B*13:01","B*49:01","B*13:02","B*15:03","B*27:01","B*42:01","B*15:02","B*45:01","B*27:02","B*39:01","B*38:02","B*39:06","B*46:01","B*40:06","B*56:01","B*53:01","B*27:08","B*27:07","B*35:07","B*50:01","B*37:01","B*52:01","B*15:17","B*55:01","B*15:10","B*14:02","B*55:02","B*54:01","B*07:04","B*27:04","B*27:06","B*58:02","B*15:186","B*27:03","B*08:02"],"y":[52482,20116,16973,15094,11470,8580,8313,8252,6807,6415,5626,5301,5233,5072,4879,4347,4248,4140,4093,3970,3931,3864,3477,3469,3435,3262,3260,3071,3042,2661,2416,2346,2215,2121,2101,1947,1925,1921,1867,1831,1793,1782,1721,1571,1516,1489,1293,1223,1084,1071,1018,0]},{"line":{"color":"#636EFA","dash":"dot"},"marker":{"color":["#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA","#636EFA"],"line":{"width":2},"size":9,"symbol":["line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns","line-ns"]},"mode":"markers","name":"MHCFlurry2.0_MS","opacity":1,"type":"scatter","x":["B*27:05","B*57:01","B*07:02","B*40:02","B*15:01","B*44:02","B*44:03","B*08:01","B*40:01","B*57:03","B*27:09","B*51:01","B*58:01","B*35:01","B*38:01","B*18:01","B*35:03","B*13:01","B*49:01","B*13:02","B*15:03","B*27:01","B*42:01","B*15:02","B*45:01","B*27:02","B ...

# %%
fig.write_image("scatterplot_A_alleles.svg", width=1100, height=400)

# %%
tmp_data = all_alleles_all_datasets[all_alleles_all_datasets.apply(lambda x: x.allele[4]=="B", axis=1)]
symbols_dict = {"MHCFlurry2.0_BA": "line-ne", \
                "NetMHCpan4.1_BA": "line-nw", \
                "MHCFlurry2.0_MS": "line-ns", \
                "NetMHCpan4.1_MS": "line-ew" }
colors_dict = {"MHCFlurry2.0_BA": px.colors.qualitative.Set1[0], \
                "NetMHCpan4.1_BA": px.colors.qualitative.Set1[0], \
                "MHCFlurry2.0_MS": px.colors.qualitative.Set1[1], \
                "NetMHCpan4.1_MS": px.colors.qualitative.Set1[1]}
allele_order_df = tmp_data[tmp_data["dataset_name"]=="MHCFlurry2.0_MS"][["allele", "peptide_counts"]]\
.sort_values(by="peptide_counts", ascending=False).reset_index(drop=True).reset_index()[["allele", "index"]]
tmp_data["symbols"] = tmp_data.dataset_name.apply(lambda x: symbols_dict[x])
tmp_data["color"] = tmp_data.dataset_name.apply(lambda x: colors_dict[x])
tmp_data["allele_order"] = tmp_data.allele.apply(lambda x: allele_order_df["index"][allele_order_df.allele==x].iloc[0])
#tmp_data = tmp_data.sort_values(by=["peptide_counts", "allele_short"], ascending=[False, True])
fig = go.Figure()
for dsn in tmp_data.dataset_name.unique():
    tmp_data_ds = tmp_data[tmp_data.dataset_name == dsn].sort_values(by="allele_order")
    tmp_data_ds_no_zeros = tmp_data_ds[tmp_data_ds["peptide_counts"]!=0]
    #tmp_data_ds = tmp_data_ds.sort_values(by="allele_short")
    
    fig.add_trace(go.Scatter(mode="lines", x=tmp_data_ds.allele_short, y=tmp_data_ds.peptide_counts, \
                             marker_symbol=tmp_data_ds.symbols, opacity=0.5, \
                             marker_line_width=1, marker_size=0, name = dsn, marker_color = tmp_data_ds.color,\
                             line_color = colors_dict[dsn], line=dict(dash='dot')
                          ))
    
    fig.add_trace(go.Scatter(mode="markers", x=tmp_data_ds_no_zeros.allele_short, y=tmp_data_ds_no_zeros.peptide_counts, \
                         marker_symbol=tmp_data_ds_no_zeros.symbols, opacity=1, \
                         marker_line_width=2, marker_size=9, name = dsn, marker_color = tmp_data_ds_no_zeros.color,\
                         line_color = colors_dict[dsn], line=dict(dash='dot')
                      ))
    fig.add_trace(go.Scatter(mode="markers", x=tmp_data_ds_no_zeros.allele_short, y=tmp_data_ds_no_zeros.peptide_counts, \
                     marker_symbol="circle-open", opacity=1, \
                     marker_line_width=2, marker_size=9, name = dsn, marker_color = tmp_data_ds_no_zeros.color,\
                     line_color = colors_dict[dsn], line=dict(dash='dot')
                  ))
                          # marker_line_width=2, marker_size=15,
                          # hovertemplate="name: %{y}%{x}<br>number: %{marker.symbol}<extra></extra>"))
fig.update_layout(width=1300, height=400, yaxis_range=[-1000, 25000], xaxis=dict(tickangle=45,\
                                                                                tick0=0, dtick=1.2))
# Out:
# <ipython-input-585-43b058abb721>:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-585-43b058abb721>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-585-43b058abb721>:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="d518500a-e4f2-41fb-920b-bb83728a160c" class="plotly-graph-div" style="height:400px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d518500a-e4f2-41fb-920b-bb83728a160c")) {                    Plotly.newPlot(                        "d518500a-e4f2-41fb-920b-bb83728a160c",                        [{"line":{"color":"rgb(55,126,184)","dash":"dot"},"marker":{"color":["rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)"],"line":{"width":1},"size":0,"symbol":["line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew"]},"mode":"lines","name":"NetMHCpan4.1_MS","opacity":0.5,"type":"scatter","x":["B*27:05","B*57:01","B*07:02","B*40:02","B*15:01","B*44:02","B*44:03","B*08:01","B*40:01","B*57:03","B*27:09","B*51:01","B*58:01","B*35:01","B*38:01","B*18:01","B*35:03","B*13:01","B*49:01","B*13:02","B*15:03","B*27:01","B*42:01","B*15:02","B*45:01","B*27:02","B*39:01","B*38:02","B*39:06","B*46:01","B*40:06","B*56:01","B*53:01","B*27:08","B*27:07","B*35:07","B*50:01","B*37:01","B*52:01","B*15:17","B*55:01","B*15:10","B*14:02","B*55:02","B*54:01","B*07:04","B*27:04","B*27:06","B*58:02","B*15:186","B*27:03","B*08:02"],"y":[9697,17896,16232,8015,11569,9204,8825,8378,5253,4804,4794,4284,3916,7323,4401,4649,4257,74,996,2086,1834,3887,10,2893,2094,3342,3063,0,3670,1918,0,921,0,2162,2146,0,1870,583,77,13,535,484,614,5,1092,0,2483,1233,7,0,1028,0]},{"line":{"color":"rgb(55,126,184)","dash":"dot"},"marker":{"color":["rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)"],"line":{"width":2},"size":9,"symbol":["line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew ...

# %%
fig.write_image("scatterplot_B_alleles.svg", width=1300, height=400)

# %%
tmp_data = all_alleles_all_datasets[all_alleles_all_datasets.apply(lambda x: x.allele[4]=="C", axis=1)]
symbols_dict = {"MHCFlurry2.0_BA": "line-ne", \
                "NetMHCpan4.1_BA": "line-nw", \
                "MHCFlurry2.0_MS": "line-ns", \
                "NetMHCpan4.1_MS": "line-ew" }
colors_dict = {"MHCFlurry2.0_BA": px.colors.qualitative.Set1[0], \
                "NetMHCpan4.1_BA": px.colors.qualitative.Set1[0], \
                "MHCFlurry2.0_MS": px.colors.qualitative.Set1[1], \
                "NetMHCpan4.1_MS": px.colors.qualitative.Set1[1]}
allele_order_df = tmp_data[tmp_data["dataset_name"]=="MHCFlurry2.0_MS"][["allele", "peptide_counts"]]\
.sort_values(by="peptide_counts", ascending=False).reset_index(drop=True).reset_index()[["allele", "index"]]
tmp_data["symbols"] = tmp_data.dataset_name.apply(lambda x: symbols_dict[x])
tmp_data["color"] = tmp_data.dataset_name.apply(lambda x: colors_dict[x])
tmp_data["allele_order"] = tmp_data.allele.apply(lambda x: allele_order_df["index"][allele_order_df.allele==x].iloc[0])
#tmp_data = tmp_data.sort_values(by=["peptide_counts", "allele_short"], ascending=[False, True])
fig = go.Figure()
for dsn in tmp_data.dataset_name.unique():
    tmp_data_ds = tmp_data[tmp_data.dataset_name == dsn].sort_values(by="allele_order")
    tmp_data_ds_no_zeros = tmp_data_ds[tmp_data_ds["peptide_counts"]!=0]
    #tmp_data_ds = tmp_data_ds.sort_values(by="allele_short")
    
    fig.add_trace(go.Scatter(mode="lines", x=tmp_data_ds.allele_short, y=tmp_data_ds.peptide_counts, \
                             marker_symbol=tmp_data_ds.symbols, opacity=0.5, \
                             marker_line_width=1, marker_size=0, name = dsn, marker_color = tmp_data_ds.color,\
                             line_color = colors_dict[dsn], line=dict(dash='dot')
                          ))
    
    fig.add_trace(go.Scatter(mode="markers", x=tmp_data_ds_no_zeros.allele_short, y=tmp_data_ds_no_zeros.peptide_counts, \
                         marker_symbol=tmp_data_ds_no_zeros.symbols, opacity=1, \
                         marker_line_width=2, marker_size=9, name = dsn, marker_color = tmp_data_ds_no_zeros.color,\
                         line_color = colors_dict[dsn], line=dict(dash='dot')
                      ))
    fig.add_trace(go.Scatter(mode="markers", x=tmp_data_ds_no_zeros.allele_short, y=tmp_data_ds_no_zeros.peptide_counts, \
                     marker_symbol="circle-open", opacity=1, \
                     marker_line_width=2, marker_size=9, name = dsn, marker_color = tmp_data_ds_no_zeros.color,\
                     line_color = colors_dict[dsn], line=dict(dash='dot')
                  ))
                          # marker_line_width=2, marker_size=15,
                          # hovertemplate="name: %{y}%{x}<br>number: %{marker.symbol}<extra></extra>"))
fig.update_layout(width=700, height=400, yaxis_range=[-1000, 25000], xaxis=dict(tickangle=45,\
                                                                                tick0=0, dtick=1.2))
# Out:
# <ipython-input-587-ef1ae2bdfbf5>:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-587-ef1ae2bdfbf5>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-587-ef1ae2bdfbf5>:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="f88ed76c-28c3-4d82-9043-77b187a064a2" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f88ed76c-28c3-4d82-9043-77b187a064a2")) {                    Plotly.newPlot(                        "f88ed76c-28c3-4d82-9043-77b187a064a2",                        [{"line":{"color":"rgb(55,126,184)","dash":"dot"},"marker":{"color":["rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)"],"line":{"width":1},"size":0,"symbol":["line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew"]},"mode":"lines","name":"NetMHCpan4.1_MS","opacity":0.5,"type":"scatter","x":["C*12:02","C*05:01","C*16:01","C*08:02","C*03:03","C*06:02","C*15:02","C*07:01","C*12:03","C*03:04","C*07:02","C*14:02","C*02:02","C*04:01","C*14:03","C*01:02","C*08:01","C*17:01","C*03:02","C*04:03"],"y":[730,5943,4247,3647,2961,3037,1917,1462,3349,2893,3190,2942,2733,2795,0,1700,101,602,0,0]},{"line":{"color":"rgb(55,126,184)","dash":"dot"},"marker":{"color":["rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)"],"line":{"width":2},"size":9,"symbol":["line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew","line-ew"]},"mode":"markers","name":"NetMHCpan4.1_MS","opacity":1,"type":"scatter","x":["C*12:02","C*05:01","C*16:01","C*08:02","C*03:03","C*06:02","C*15:02","C*07:01","C*12:03","C*03:04","C*07:02","C*14:02","C*02:02","C*04:01","C*01:02","C*08:01","C*17:01"],"y":[730,5943,4247,3647,2961,3037,1917,1462,3349,2893,3190,2942,2733,2795,1700,101,602]},{"line":{"color":"rgb(55,126,184)","dash":"dot"},"marker":{"color":["rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)","rgb(55,126,184)"],"line":{"width":2},"size":9,"symbol":"circle-open"},"mode":"markers","name":"NetMHCpan4.1_MS","opacity":1,"type":"scatter","x":["C*12:02","C*05:01","C*16:01","C*08:02","C*03:03","C*06:02","C*15:02","C*07:01","C*12:03","C*03:04","C*07:02","C*14:02","C*02:02","C*04:01","C*01:02","C*08:01","C*17:01"],"y":[730,5943,4247,3647,2961,3037,1917,1462,3349,2893,3190,2942,2733,2795,1700,101,602]},{"line":{"color":"rgb(228,26,28)","dash":"dot"},"marker":{"color":["rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)","rgb(228,26,28)"],"line":{"width":1},"size":0,"symbol":["line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw","line-nw"]},"mode":"lines","name":"NetMHCpan4.1_BA","opacity":0.5,"type":"scatter","x":["C*12:02","C*05:01" ...

# %%
fig.write_image("scatterplot_C_alleles.svg", width=700, height=400)

# %%
fig_A.write_image("barplot_A_alleles.svg", width=1500, height=600)

# %%
#all_data["proc"] = all_data["freq"].apply(lambda x: x*100)
fig_B = px.bar(all_data_freqs[all_data_freqs.apply(lambda x: x.allele[4]=="B" and x.peptide > 0.1, axis=1)]\
             , x="allele_short", y="peptide", color='dataset_name', barmode="group", width=1500, height=300)
fig_B.update_xaxes(title="<b>HLA Allele</b>", titlefont = dict(size = 18), tickfont = dict(size = 15), tickangle = 45)
fig_B.update_yaxes(title="<b>percent within the dataset</b>", titlefont = dict(size = 18), tickfont = dict(size = 15))
#fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="black")
fig_B.update_layout(showlegend=False, yaxis=dict(range=[0,11]))
fig_B.show()
# Out:
# <div>                            <div id="3de4f0bf-18fd-44a3-8e17-88db929a1573" class="plotly-graph-div" style="height:300px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3de4f0bf-18fd-44a3-8e17-88db929a1573")) {                    Plotly.newPlot(                        "3de4f0bf-18fd-44a3-8e17-88db929a1573",                        [{"alignmentgroup":"True","hovertemplate":"dataset_name=netmhc<br>allele_short=%{x}<br>peptide=%{y}<extra></extra>","legendgroup":"netmhc","marker":{"color":"#636efa","pattern":{"shape":""}},"name":
# %%
fig_B.write_image("barplot_B_alleles.svg", width=1500, height=300)

# %%
#all_data["proc"] = all_data["freq"].apply(lambda x: x*100)
fig_C = px.bar(all_data_freqs[all_data_freqs.apply(lambda x: x.allele[4]=="C" and x.peptide > 0.1, axis=1)]\
             , x="allele_short", y="peptide", color='dataset_name', barmode="group", width=700, height=300)
fig_C.update_xaxes(title="<b>HLA Allele</b>", titlefont = dict(size = 18), tickfont = dict(size = 15), tickangle = 45)
fig_C.update_yaxes(title="<b>percent within the dataset</b>", titlefont = dict(size = 18), tickfont = dict(size = 15))
#fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="black")
fig_C.update_layout(showlegend=False, yaxis=dict(range=[0,5]))
fig_C.show()
# Out:
# <div>                            <div id="1f0c01e9-9faa-4173-b1ba-805d42aa9831" class="plotly-graph-div" style="height:300px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f0c01e9-9faa-4173-b1ba-805d42aa9831")) {                    Plotly.newPlot(                        "1f0c01e9-9faa-4173-b1ba-805d42aa9831",                        [{"alignmentgroup":"True","hovertemplate":"dataset_name=netmhc<br>allele_short=%{x}<br>peptide=%{y}<extra></extra>","legendgroup":"netmhc","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"netmhc","offsetgroup":"netmhc","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["C*01:02","C*02:02","C*03:03","C*03:04","C*04:01","C*05:01","C*06:02","C*07:01","C*07:02","C*08:02","C*12:02","C*12:03","C*14:02","C*15:02","C*16:01","C*17:01"],"xaxis":"x","y":[0.5103051624871673,0.8203905935749578,0.8888315212497073,0.8684193147502206,0.8390017230303721,1.7839668121536678,0.9116451638079571,0.4388624397389639,0.9575726284318022,1.0947546632886467,0.21913104036213657,1.0053011700997196,0.8831281106101448,0.5754441155811175,1.2748623676958821,0.1807080634219263],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"dataset_name=mhcflurry<br>allele_short=%{x}<br>peptide=%{y}<extra></extra>","legendgroup":"mhcflurry","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"mhcflurry","offsetgroup":"mhcflurry","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["C*01:02","C*02:02","C*03:02","C*03:03","C*03:04","C*04:01","C*04:03","C*05:01","C*06:02","C*07:01","C*07:02","C*07:04","C*08:01","C*08:02","C*12:02","C*12:03","C*14:02","C*14:03","C*15:02","C*16:01","C*17:01"],"xaxis":"x","y":[0.4911522513578228,0.6527282991687594,0.24859350970429636,0.925655551013257,0.801261461192548,0.6383227238217603,0.2205610387587845,1.169966322100878,0.886721563588935,0.8436995074850591,0.7085985711226616,0.17520294340944928,0.37473962895909985,1.022601179699819,2.174073857774144,0.8174190659736417,0.6879635577877709,0.5812844322451284,0.8444781872335455,1.110007981467422,0.28577546769452394],"yaxis":"y"}],                        {"barmode":"group","height":300,"legend":{"title":{"text":"dataset_name"},"tracegroupgap":0},"margin":{"t":60},"showlegend":false,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar": ...

# %%
fig_C.write_image("barplot_C_alleles.svg", width=650, height=300)

# %% [markdown]
# ## Visualize dataset balance our AFND curated data - IEDB pop coverage tool

# %%
#result_files = [tmp for tmp in os.listdir("output_dataset_balance_afnd") if "pop_cov" in tmp]
#ideal_pc_files = [tmp for tmp in os.listdir("iedb_pc_results") if tmp[-8:]=="ideal.txt"]
#result_files = result_files[1:]

# %%
result_df_afnd = pd.read_csv("./output_dataset_balance_afnd/all_results.csv")
result_df_afnd = result_df_afnd[["population", "dataset", "js_div"]]

# %%
result_df_afnd
# Out:
#                                   population    dataset    js_div
# 0                             American Samoa   hlathena  0.620448
# 1                             American Samoa  mhcflurry  0.425913
# 2                             American Samoa     netmhc  0.503264
# 3    Australia Cape York Peninsula Aborigine   hlathena  0.605182
# 4    Australia Cape York Peninsula Aborigine  mhcflurry  0.448087
# ..                                       ...        ...       ...
# 766                            Zambia Lusaka  mhcflurry  0.273066
# 767                            Zambia Lusaka     netmhc  0.377838
# 768                    Zimbabwe Harare Shona   hlathena  0.437495
# 769                    Zimbabwe Harare Shona  mhcflurry  0.229575
# 770                    Zimbabwe Harare Shona     netmhc  0.336515
#
# [771 rows x 3 columns]

# %%
afnd_df = pd.read_csv("AFND_data_locus_all.csv")

# %%
pop_continent_map = afnd_df.groupby(by=["Population", "country", "continent"]).sum().reset_index()
#pop_continent_map["Population"] = pop_continent_map["Population"].apply(lambda x: x.replace(" ", "").replace("/", ""))
#result_df_afnd.population = result_df_afnd.population.apply(lambda x: x.replace("_", "").replace(" ", "").replace("/", ""))

# %%
def find_country_continent(pop_continent_map, population):
    if population in pop_continent_map.Population.unique():
        return pop_continent_map[pop_continent_map.Population == population].country.iloc[0], \
        pop_continent_map[pop_continent_map.Population == population].continent.iloc[0]
    else:
        return None, None

# %%
result_df_afnd["country"] = result_df_afnd.population.apply(lambda x: find_country_continent(pop_continent_map, x)[0])
result_df_afnd["continent"] =result_df_afnd.population.apply(lambda x: find_country_continent(pop_continent_map, x)[1])

# %%
#all_results = all_results.sort_values(by=['dataset', "population"], ascending=[False, True])

# %%
result_df_afnd["dataset balance"] = result_df_afnd.js_div.apply(lambda x: 1-x)

# %%
result_df_afnd = result_df_afnd.sort_values(by=["dataset"], ascending=[False])

# %%
fig = px.box(result_df_afnd, x="continent", y="dataset balance", color="dataset",width=800, height=500, points="all")
fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
fig.show()
# Out:
# <div>                            <div id="78caa5b8-0f46-4313-85af-f087b512b546" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78caa5b8-0f46-4313-85af-f087b512b546")) {                    Plotly.newPlot(                        "78caa5b8-0f46-4313-85af-f087b512b546",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"dataset=netmhc<br>continent=%{x}<br>dataset balance=%{y}<extra></extra>","legendgroup":"netmhc","marker":{"color":"#636efa"},"name":"netmhc","notched":false,"offsetgroup":"netmhc","orientation":"v","showlegend":true,"type":"box","x":["Africa","Asia","North America","Asia","South America","Asia","North America","South America","Asia","Asia","South America","Asia","South America","Asia","North America","South America","North America","Asia","North America","Asia","Asia","North America","North America","Asia","North America","Asia","North America","Asia","Asia","North America","Oceania","Asia","Europe","Asia","Asia","South America","North America","North America","Asia","Oceania","North America","Asia","Europe","North America","Asia","Europe","North America","Asia","Oceania","North America","Asia","South America","Asia","Europe","North America","South America","Oceania","North America","South America","Africa","South America","Asia","Asia","South America","Oceania","Asia","South America","Asia","Europe","Asia","Europe","Asia","Europe","Asia","Europe","Asia","Asia","Europe","South America","Asia","Europe","Europe","Europe","Asia","Europe","South America","Europe","Europe","Europe","Europe","Europe","Asia","Europe","Europe","Asia","Europe","Africa","Europe","Europe","North America","Europe","Oceania","Asia","Asia","Asia","Europe","Oceania","Asia","Europe","Asia","Europe","Asia","Africa","Asia","Oceania","Asia","Asia","Africa","Asia","Africa","Asia","Europe","Oceania","Africa","Europe","Africa","Asia","Asia","Asia","Europe","Oceania","Asia","Europe","Asia","Europe","Asia","Europe","North America","North America","Asia","North America","South America","North America","North America","South America","North America","South America","Europe","North America","Europe","North America","North America","Africa","Africa","Africa","Africa","North America","Africa","North America","North America","North America","North America","North America","Africa","North America","North America","North America","South America","North America","South America","North America","South America","North America","Oceania","North America","Africa","Oceania","North America","Asia","Oceania","Asia","Oceania","Africa","South America","Oceania","North America","Asia","Oceania","Africa","South America","Asia","Africa","South America","North America","North America","South America","North America","South America","Asia","North America","South America","North America","South America","North America","North America","Asia","North America","Asia","North America","Europe","North America","Asia","Asia","North America","Asia","Asia","Asia","Africa","North America","North America","Asia","North America","Asia","Asia","North America","Europe","Asia","Asia","Europe","North America","Asia","Africa","Asia","North America","Asia","Asia","North America","North America","North America","Oceania","Asia","Asia","North America","Asia","Asia","North America","North America","Asia","Asia","Asia","Asia","North America","North America","North America","Asia","North America","Africa"],"x0":" ","xaxis":"x","y":[0.6634854800514187,0.3467248768927369,0.6852477658506445,0.3690702731366863,0.34525162536901266,0.34442698414629236,0.7879570535614369,0.30116667564422905,0.44338083093791925,0.6852944204769462,0.35206406668963697,0.4563159525781406,0.48942196299470664,0.32987833346517803,0.7960106674405194,0.327858319512 ...

# %%
fig.write_image("dataset_afnd_balance.svg", width=800, height=500)

# %%
global_south_77 = pd.read_csv("global_south_77.txt", header=None)
global_south_77.columns = ["country"]
global_south_77 = global_south_77.append({"country": "China"}, ignore_index=True)
# Out:
# <ipython-input-17-e96176dd4f07>:3: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
def map_population_to_gs_gn(population):
    if global_south_77.country.apply(lambda x: x in population).any():
        if "Caucasian" in population:
            return "Global North"
        return "Global South"
    else:
        if "African" in population or "Aborigine" in population or "Asian" in population \
        or "Vietnam" in population \
        or "Hispanic" in population or "Mexican" in population or "Vietnamese" in population\
        or "Maori" in population or "Polynesians" in population or "Sao Tome Island" in population:
            return "Global South"
        return "Global North"

# %%
gn_gs_map = { pop: map_population_to_gs_gn(pop) for pop in afnd_df.Population.unique()}

# %%
gn_gs_map
# Out:
# {'American Samoa': 'Global South',
#  'Australia Cape York Peninsula Aborigine': 'Global South',
#  'Australia Groote Eylandt Aborigine': 'Global South',
#  'Australia Kimberly Aborigine': 'Global South',
#  'Australia New South Wales Caucasian': 'Global North',
#  'Australia Yuendumu Aborigine': 'Global South',
#  'Bolivia/Chile Aymara NA-DHS_13 (G)': 'Global South',
#  'Bolivia/Peru Quechua NA-DHS_12 (G)': 'Global South',
#  'Brazil Barra Mansa Rio State Black': 'Global South',
#  'Brazil Barra Mansa Rio State Caucasian': 'Global North',
#  'Brazil Mixed': 'Global South',
#  'Brazil Puyanawa': 'Global South',
#  'Brazil Rio de Janeiro Black': 'Global South',
#  'Brazil Rio de Janeiro Caucasian': 'Global North',
#  'Brazil Rio de Janeiro Parda': 'Global South',
#  'Brazil Terena': 'Global South',
#  'Bulgaria Romani': 'Global North',
#  'Cameroon Baka Pygmy': 'Global South',
#  'Cameroon Beti': 'Global South',
#  'Cameroon Sawa': 'Global South',
#  'Canada Chipewyan NA-DHS_2 (G)': 'Global North',
#  'Canada Cree NA-DHS_3 (G)': 'Global North',
#  'Canada Ojibwa NA-DHS_4 (G)': 'Global North',
#  'Chile Easter Island': 'Global South',
#  'Chile Huilliche NA-DHS_14 (G)': 'Global South',
#  'China Beijing': 'Global South',
#  'China Canton Han': 'Global South',
#  'China Guangdong Province Meizhou Han': 'Global South',
#  'China Guangzhou': 'Global South',
#  'China Guizhou Province Bouyei': 'Global South',
#  'China Guizhou Province Miao pop 2': 'Global South',
#  'China Guizhou Province Shui': 'Global South',
#  'China Han HIV negative': 'Global South',
#  'China Henan HIV negative': 'Global South',
#  'China Hubei Han': 'Global South',
#  'China Inner Mongolia Region': 'Global South',
#  'China Jingpo Minority': 'Global South',
#  'China Marrow Donor Registry': 'Global South',
#  'China North Han': 'Global South',
#  'China Qinghai Province Hui': 'Global South',
#  'China Shanxi HIV negative': 'Global South',
#  'China Sichuan HIV negative': 'Global South',
#  'China South Han': 'Global South',
#  'China Southwest Dai': 'Global South',
#  'China Tibet Region Tibetan': 'Global South',
#  'China Uyghur HIV negative': 'Global South',
#  'China Yunnan Bulang': 'Global South',
#  'China Yunnan Hani': 'Global South',
#  'China Yunnan Province Han': 'Global South',
#  'China Yunnan Province Lisu': 'Global South',
#  'China Zhejiang Han': 'Global South',
#  'Colombia Arhuaco NA-DHS_16 (G)': 'Global South',
#  'Colombia Bogota Cord Blood': 'Global South',
#  'Colombia Embera NA-DHS_19 (G)': 'Global South',
#  'Colombia Inga NA-DHS_11 (G)': 'Global South',
#  'Colombia Kogi NA-DHS_17 (G)': 'Global South',
#  'Colombia North Chimila Amerindians': 'Global South',
#  'Colombia North Wiwa El Encanto': 'Global South',
#  'Colombia Waunana NA-DHS_20 (G)': 'Global South',
#  'Colombia Wayuu NA-DHS_15 (G)': 'Global South',
#  'Colombia Zenu NA-DHS_18 (G)': 'Global South',
#  'Colombia/Brazil Ticuna Arara NA-DHS_21 (G)': 'Global South',
#  'Colombia/Brazil Ticuna Tarapaca NA-DHS_22 (G)': 'Global South',
#  'Costa Rica African -Caribbean (G)': 'Global South',
#  'Costa Rica Amerindians (G)': 'Global South',
#  'Costa Rica Cabecar NA-DHS_9 (G)': 'Global South',
#  'Costa Rica Central Valley Mestizo (G)': 'Global South',
#  'Costa Rica Guanacaste Mestizo (G)': 'Global South',
#  'Costa Rica Guaymi NA-DHS_10 (G)': 'Global South',
#  'Czech Republic NMDR': 'Global North',
#  'England Blood Donors of Mixed Ethnicity': 'Global North',
#  'England North West': 'Global North',
#  'Finland': 'Global North',
#  'France Southeast': 'Global North',
#  'Gaza': 'Global North',
#  'Georgia Tibilisi': 'Global North',
#  'Georgia Tibilisi Kurd': 'Global North',
#  'Germany DKMS - Austria minority': 'Global North',
#  'Germany DKMS - Bosnia and Herzegovina minority': 'Global North',
#  'Germany DKMS - China minority': 'Global South',
#  'Germany DKMS - Croatia minority': 'Global North',
#  'Germany DKMS - France minority': 'Global North',
#  'Germany DKMS - German donors': 'Global North',
#  'Germany DKMS - Greece minority': 'Global North',
#  'Germany DKMS - Italy minority': 'Global North',
#  'Germany DKMS - Netherlands minority': 'Global North',
#  'Germany DKMS - Portugal minority': 'Global North',
#  'Germany DKMS - Romania minority': 'Global North',
#  'Germany DKMS - Spain minority': 'Global North',
#  'Germany DKMS - Turkey minority': 'Global North',
#  'Germany DKMS - United Kingdom minority': 'Global North',
#  'Germany pop 6': 'Global North',
#  'Germany pop 8': 'Global North',
#  'Ghana Ga-Adangbe': 'Global South',
#  'Greece pop 6': 'Global North',
#  'Greece pop 8': 'Global North',
#  'Guatemala Kaqchikel NA-DHS_8 (G)': 'Global South',
#  'Hong Kong Chinese BMDR': 'Global North',
#  'Hong Kong Chinese HKBMDR HLA 11 loci': 'Global North',
#  'India Andhra Pradesh Telugu Speaking': 'Global South',
#  'India Karnataka Kannada Speaking': 'Global South',
#  'India Kerala Malayalam speaking': 'Global South',
#  'India Khandesh Region Pawra': 'Global South',
#  'India Mumbai Maratha': 'Global South',
#  'India New Delhi': 'Global South',
#  'India Tamil Nadu': 'Global South',
#  'India Tamil Nadu Nadar': 'Global South',
#  'India West Coast Parsi': 'Global South',
#  'Iran Baloch': 'Global South',
#  'Iran Gorgan': 'Global South',
#  'Ireland Northern': 'Global North',
#  'Ireland South': 'Global North',
#  'Israel Arab Druze': 'Global North',
#  'Israel Ashkenazi and Non Ashkenazi Jews': 'Global North',
#  'Italy pop 5': 'Global North',
#  'Japan Central': 'Global North',
#  'Japan pop 16': 'Global North',
#  'Japan pop 3': 'Global North',
#  'Japan pop 5': 'Global North',
#  'Kenya': 'Global South',
#  'Kenya Luo': 'Global South',
#  'Kenya Nandi': 'Global South',
#  'Kenya, Nyanza Province, Luo tribe': 'Global South',
#  'Kosovo': 'Global North',
#  'Malaysia Peninsular Chinese': 'Global South',
#  'Malaysia Peninsular Indian': 'Global South',
#  'Malaysia Peninsular Malay': 'Global South',
#  'Mali Bandiagara': 'Global South',
#  'Mexico Chiapas Lacandon Mayans': 'Global South',
#  'Mexico Chihuahua Tarahumara': 'Global South',
#  'Mexico Hidalgo Mezquital Valley/ Otomi': 'Global South',
#  'Mexico Mexico City Mestizo pop 2': 'Global South',
#  'Mexico Mexico City Mestizo population': 'Global South',
#  'Mexico Mixe NA-DHS_6 (G)': 'Global South',
#  'Mexico Mixtec NA-DHS_5 (G)': 'Global South',
#  'Mexico Oaxaca Mixe': 'Global South',
#  'Mexico Oaxaca Mixtec': 'Global South',
#  'Mexico Oaxaca Zapotec': 'Global South',
#  'Mexico Zapotec NA-DHS_7 (G)': 'Global South',
#  'Morocco Atlantic Coast Chaouya': 'Global South',
#  'Morocco Nador Metalsa pop 2': 'Global South',
#  'Morocco Settat Chaouya': 'Global South',
#  'Netherlands Leiden': 'Global North',
#  'Netherlands UMCU': 'Global North',
#  'New Caledonia': 'Global North',
#  'New Zealand Maori with Admixed History': 'Global South',
#  'New Zealand Maori with Full Ancestry': 'Global South',
#  'New Zealand Polynesians with Admixed History': 'Global South',
#  'New Zealand Polynesians with Full Ancestry': 'Global South',
#  'Nicaragua Managua': 'Global South',
#  'Nicaragua Mestizo (G)': 'Global South',
#  'Panama': 'Global South',
#  'Papua New Guinea East New Britain Rabaul': 'Global South',
#  'Papua New Guinea Eastern Highlands Goroka Asaro': 'Global South',
#  'Papua New Guinea Karimui Plateau Pawaia': 'Global South',
#  'Papua New Guinea Madang': 'Global South',
#  'Papua New Guinea West Schrader Ranges Haruai': 'Global South',
#  'Papua New Guinea Wosera Abelam': 'Global South',
#  'Paraguay/Argentina Ache NA-DHS_24 (G)': 'Global South',
#  'Paraguay/Argentina Guarani NA-DHS_23 (G)': 'Global South',
#  'Philippines Ivatan': 'Global South',
#  'Poland': 'Global North',
#  'Poland BMR': 'Global North',
#  'Poland DKMS': 'Global North',
#  'Portugal Azores Terceira Island': 'Global North',
#  'Russia Belgorod region': 'Global North',
#  'Russia Bering Island Aleuts': 'Global North',
#  'Russia Karelia': 'Global North',
#  'Russia Nizhny Novgorod, Russians': 'Global North',
#  'Russia Tundra Nentsi NA-DHS_1 (G)': 'Global North',
#  'Russia Tuva pop 2': 'Global North',
#  'Saudi Arabia Guraiat and Hail': 'Global South',
#  'Saudi Arabia pop 6 (G)': 'Global South',
#  'Singapore Javaneses': 'Global South',
#  'Singapore Riau Malay': 'Global South',
#  'Singapore SGVP Chinese CHS': 'Global South',
#  'Singapore SGVP Malay MAS': 'Global South',
#  'Singapore SGVP. Indian INS': 'Global South',
#  'Singapore Thai': 'Global South',
#  'South Africa Caucasians': 'Global North',
#  'South Africa Natal Tamil': 'Global South',
#  'South Africa Worcester': 'Global South',
#  'South African Black': 'Global South',
#  'South African Indian population': 'Global South',
#  'South African Mixed ancestry': 'Global South',
#  'South Korea pop 3': 'Global North',
#  'Spain (Catalunya, Navarra, Extremadura, Aaragón, Cantabria,': 'Global North',
#  'Spain, Canary Islands, Gran canaria island': 'Global North',
#  'Sri Lanka Colombo': 'Global South',
#  'Taiwan Ami': 'Global South',
#  'Taiwan Atayal': 'Global South',
#  'Taiwan Bunun': 'Global South',
#  'Taiwan Hakka': 'Global South',
#  'Taiwan Han Chinese': 'Global South',
#  'Taiwan Minnan pop 1': 'Global South',
#  'Taiwan Paiwan': 'Global South',
#  'Taiwan Pazeh': 'Global South',
#  'Taiwan Puyuma': 'Global South',
#  'Taiwan Rukai': 'Global South',
#  'Taiwan Saisiat': 'Global South',
#  'Taiwan Siraya': 'Global South',
#  'Taiwan Tao': 'Global South',
#  'Taiwan Taroko': 'Global South',
#  'Taiwan Thao': 'Global South',
#  'Taiwan Tsou': 'Global South',
#  'Taiwan pop 2': 'Global South',
#  'Tanzania Maasai': 'Global South',
#  'USA African American': 'Global South',
#  'USA African American Bethesda': 'Global South',
#  'USA African American pop 3': 'Global South',
#  'USA African American pop 4': 'Global South',
#  'USA Alaska Yupik': 'Global North',
#  'USA Arizona Gila River Amerindian': 'Global North',
#  'USA Arizona Gila River Pima': 'Global North',
#  'USA Asian': 'Global South',
#  'USA Asian pop 2': 'Global South',
#  'USA Caucasian Bethesda': 'Global North',
#  'USA Caucasian pop 2': 'Global North',
#  'USA Caucasian pop 4': 'Global North',
#  'USA Eastern European': 'Global North',
#  'USA Hawaii Okinawa': 'Global North',
#  'USA Hispanic': 'Global South',
#  'USA Hispanic pop 2': 'Global South',
#  'USA Italy Ancestry': 'Global North',
#  'USA Mexican American Mestizo': 'Global South',
#  'USA NMDP African': 'Global South',
#  'USA NMDP African American pop 2': 'Global South',
#  'USA NMDP Alaska Native or Aleut': 'Global North',
#  'USA NMDP American Indian South or Central America': 'Global South',
#  'USA NMDP Caribean Black': 'Global North',
#  'USA NMDP Caribean Hispanic': 'Global South',
#  'USA NMDP Caribean Indian': 'Global South',
#  'USA NMDP Chinese': 'Global North',
#  'USA NMDP European Caucasian': 'Global North',
#  'USA NMDP Filipino': 'Global North',
#  'USA NMDP Hawaiian or other Pacific Islander': 'Global North',
#  'USA NMDP Hispanic South or Central American': 'Global South',
#  'USA NMDP Japanese': 'Global North',
#  'USA NMDP Korean': 'Global North',
#  'USA NMDP Mexican or Chicano': 'Global South',
#  'USA NMDP Middle Eastern or North Coast of Africa': 'Global North',
#  'USA NMDP North American Amerindian': 'Global North',
#  'USA NMDP South Asian Indian': 'Global South',
#  'USA NMDP Southeast Asian': 'Global South',
#  'USA NMDP Vietnamese': 'Global South',
#  'USA New Mexico Canoncito Navajo': 'Global South',
#  'USA North American Native': 'Global North',
#  'USA Philadelphia Caucasian': 'Global North',
#  'USA San Antonio Caucasian': 'Global North',
#  'USA San Diego': 'Global North',
#  'USA San Francisco Caucasian': 'Global North',
#  'USA South Dakota Lakota Sioux': 'Global North',
#  'USA South Texas Hispanic': 'Global South',
#  'Uganda Kampala': 'Global South',
#  'Uganda Kampala pop 2': 'Global South',
#  'United Arab Emirates Abu Dhabi': 'Global South',
#  'Venezuela Sierra de Perija Yucpa': 'Global South',
#  'Vietnam Hanoi Kinh pop 2': 'Global South',
#  'Vietnam Kinh': 'Global South',
#  'Zambia Lusaka': 'Global South',
#  'Zimbabwe Harare Shona': 'Global South'}

# %%
result_df_afnd["GlobalSouth/GlobalNorth"] = result_df_afnd.population.apply(lambda x: gn_gs_map[x])

# %%
fig = px.violin(result_df_afnd, x="GlobalSouth/GlobalNorth", y="dataset balance", points="all", \
             color="dataset",width=650, height=500, orientation="v")
fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
fig.show()
# Out:
# <div>                            <div id="f6e182e4-6404-4338-bf4e-9c6f5d784022" class="plotly-graph-div" style="height:500px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6e182e4-6404-4338-bf4e-9c6f5d784022")) {                    Plotly.newPlot(                        "f6e182e4-6404-4338-bf4e-9c6f5d784022",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"dataset=netmhc<br>GlobalSouth/GlobalNorth=%{x}<br>dataset balance=%{y}<extra></extra>","legendgroup":"netmhc","marker":{"color":"#636efa"},"name":"netmhc","offsetgroup":"netmhc","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"type":"violin","x":["Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global South","Global North","Global North","Global South","Global North","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global South","Global North","Global South","Global North","Global South","Global North","Global South","Global South","Global North","Global South","Global South","Global North","Global North","Global North","Global North","Global North","Global South","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global South","Global North","Global South","Global North","Global North","Global South","Global North","Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global North","Global North","Global North","Global South","Global South","Global North","Global South","Global South","Global North","Global South","Global North","Global South","Global South","Global North","Global South","Global South","Global North","Global North","Global South","Global South","Global South","Global North","Global South","Global South","Global North","Global South","Global North","Global North","Global North","Global South","Global South","Global South","Global North","Global North","Global South","Global North","Global South","Global South","Global South","Global North","Global South","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global North","Global North","Global South","Global North","Global South","Global North","Global South","Global North","Global South","Global South","Global South","Global North","Global South","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global North","Global South","Global North","Global South","Global South","Global South","Global North","Global North","Global South","Global South","Global South","Global Nort ...

# %%
fig.write_image("dataset_afnd_balance_gs_gn.svg", width=650, height=500)

# %% [markdown]
# ## Visualize dataset balance IEDB ethnicities - IEDB pop coverage tool

# %%
import os

# %%
result_df = pd.read_csv("./output_dataset_balance_iedb/all_results.csv")
result_df = result_df[["population", "dataset", "js_div"]]
result_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-43207e94e8bf> in <module>
# ----> 1 result_df = pd.read_csv("./output_dataset_balance_iedb/all_results.csv")
#       2 result_df = result_df[["population", "dataset", "js_div"]]
#       3 result_df
#
# ~\Miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Miniconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678     kwds.update(kwds_defaults)
#     679
# --> 680     return _read(filepath_or_buffer, kwds)
#     681
#     682
#
# ~\Miniconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\Miniconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     931
#     932         self.handles: IOHandles | None = None
# --> 933         self._engine = self._make_engine(f, self.engine)
#     934
#     935     def close(self):
#
# ~\Miniconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1215             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217             self.handles = get_handle(  # type: ignore[call-overload]
#    1218                 f,
#    1219                 mode,
#
# ~\Miniconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     787         if ioargs.encoding and "b" not in ioargs.mode:
#     788             # Encoding
# --> 789             handle = open(
#     790                 handle,
#     791                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './output_dataset_balance_iedb/all_results.csv'

# %%
iedb_pop_map = pd.read_csv("./IEDB_population_map.csv")
iedb_pop_map = iedb_pop_map[["area", "country", "population", "ethnicity"]]
iedb_pop_map
# Out:
#                area       country               population    ethnicity
# 0         East Asia         Japan           Japan Oriental     Oriental
# 1         East Asia  Korea; South    Korea; South Oriental     Oriental
# 2         East Asia      Mongolia        Mongolia Oriental     Oriental
# 3    Northeast Asia         China           China Oriental     Oriental
# 4    Northeast Asia     Hong Kong       Hong Kong Oriental     Oriental
# ..              ...           ...                      ...          ...
# 156         Oceania      Kiribati     Kiribati Micronesian  Micronesian
# 157         Oceania   New Zealand   New Zealand Polynesian   Polynesian
# 158         Oceania          Fiji          Fiji Melanesian   Melanesian
# 159         Oceania         Nauru        Nauru Micronesian  Micronesian
# 160         Oceania  Cook Islands  Cook Islands Polynesian   Polynesian
#
# [161 rows x 4 columns]

# %%
iedb_pop_map["population_no_suffix"] = iedb_pop_map.population.apply(lambda x: " ".join(x.split()[:-1]))

# %%
def match_population_to_iedb_map(population, iedb_map_df, column):
    
    try1 = iedb_map_df[iedb_map_df.population_no_suffix==population]
    if try1.shape[0] > 0:
        return try1.iloc[0][column]
    
    try2 = iedb_map_df[iedb_map_df.population==population]
    if try2.shape[0] > 0:
        return try2.iloc[0][column]
    return "?"

# %%
result_df["area"] = result_df.population.apply(lambda x: match_population_to_iedb_map(x, iedb_pop_map, "area"))
result_df["country"] = result_df.population.apply(lambda x: match_population_to_iedb_map(x, iedb_pop_map, "country"))
result_df["ethnicity"] = result_df.population.apply(lambda x: match_population_to_iedb_map(x, iedb_pop_map, "ethnicity"))

# %%
result_df[result_df["area"]=="?"].population.unique()
# Out:
# array(['Amerindian', 'Arab', 'Asian', 'Australian Aborigines',
#        'Austronesian', 'Black', 'Caucasoid', 'Central Africa',
#        'East Africa', 'East Asia', 'Europe', 'Hispanic', 'Jew', 'Kurd',
#        'Melanesian', 'Mestizo', 'Mixed', 'North Africa', 'North America',
#        'Northeast Asia', 'Oceania', 'Oriental', 'Other', 'Persian',
#        'Polynesian', 'Siberian', 'South America', 'South Asia',
#        'Southeast Asia', 'Southwest Asia', 'West Africa', 'West Indies',
#        'World'], dtype=object)

# %%
result_df = result_df[~(result_df["area"]=="?")].reset_index()

# %%
result_df["dataset balance"] = result_df.js_div.apply(lambda x: 1-x)

# %%
result_df
# Out:
#      index                 population    dataset    js_div         area  \
# 0        0             American Samoa   hlathena  0.623349      Oceania
# 1        1             American Samoa  mhcflurry  0.433333      Oceania
# 2        2             American Samoa     netmhc  0.509325      Oceania
# 3        3  American Samoa Polynesian     netmhc  0.509325      Oceania
# 4       13                  Australia   hlathena  0.572915      Oceania
# ..     ...                        ...        ...       ...          ...
# 359    458                   Zimbabwe  mhcflurry  0.243802  East Africa
# 360    459                   Zimbabwe     netmhc  0.350945  East Africa
# 361    460             Zimbabwe Black   hlathena  0.447735  East Africa
# 362    461             Zimbabwe Black  mhcflurry  0.243802  East Africa
# 363    462             Zimbabwe Black     netmhc  0.350945  East Africa
#
#             country   ethnicity  dataset balance
# 0    American Samoa  Polynesian         0.376651
# 1    American Samoa  Polynesian         0.566667
# 2    American Samoa  Polynesian         0.490675
# 3    American Samoa  Polynesian         0.490675
# 4         Australia   Caucasoid         0.427085
# ..              ...         ...              ...
# 359        Zimbabwe       Black         0.756198
# 360        Zimbabwe       Black         0.649055
# 361        Zimbabwe       Black         0.552265
# 362        Zimbabwe       Black         0.756198
# 363        Zimbabwe       Black         0.649055
#
# [364 rows x 8 columns]

# %%
result_df = result_df.sort_values(by=["ethnicity", "dataset"], ascending=[True, False])

# %%
fig = px.box(result_df[~result_df.ethnicity.isin(["Mixed", "Mulato", "Mestizo", "Jew", \
                                                  "Siberian", "Hispanic", "Persian", "Other"])], \
             x="ethnicity", y="dataset balance", color="dataset",width=1000, height=500, points="all")
fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
def map_population_to_gs_gn_iedb(population):
    if global_south_77.country.apply(lambda x: x in population).any():
        if "Caucasoid" in population:
            return "Global North"
        return "Global South"
    else:
        if "African" in population or "Aborigine" in population or "Asian" in population \
        or "Vietnam" in population \
        or "Hispanic" in population or "Mexican" in population or "Vietnamese" in population\
        or "Black" in population or "Amerindian" in population or "Hispanic" in population \
        or "Austronesian" in population or "Austronesian" in population \
        or "Maori" in population or "Polynesians" in population or "Sao Tome Island" in population:
            return "Global South"
        return "Global North"

# %%
result_df["GlobalSouth/GlobalNorth"] = result_df.population.apply(lambda x: map_population_to_gs_gn_iedb(x))

# %%
fig = px.violin(result_df[~result_df.ethnicity.isin(["Mixed", "Mulato", "Mestizo", "Other"])], \
             x="GlobalSouth/GlobalNorth", y="dataset balance", color="dataset",width=800, height=500, points="all")
fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
fig.show()
# Out:
# <div>                            <div id="4a37b143-b44d-4033-8eed-29c45742e249" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a37b143-b44d-4033-8eed-29c45742e249")) {                    Plotly.newPlot(                        "4a37b143-b44d-4033-8eed-29c45742e249",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"dataset=netmhc<br>GlobalSouth/GlobalNorth=%{x}<br>dataset balance=%{y}<extra></extra>","legendgroup":"netmhc","marker":{"color":"#636efa"},"name":"netmhc","offsetgroup":"netmhc","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"type":"violin","x":["Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global South","Global North","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global South","Global North","Global North","Global South","Global North","Global North","Global South","Global South","Global South","Global South","Global North","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global North"],"x0":" ","xaxis":"x","y":[0.4287898741631774,0.7526197164108043,0.44658111217333085,0.6118428154890929,0.4253822136635371,0.5377795321553782,0.49294696142088945,0.4452837868010865,0.808694537253175,0.5434873486785713,0.3482878822932908,0.3477659067161596,0.8341785508288035,0.7355044403927059,0.8536143353618055,0.8536143353618055,0.7105619952978324,0.6719980756384434,0.6770810929029826,0.6770810929029826,0.6803771882076954,0.6917932736971494,0.7851897198072354,0.7851897198072354,0.7611948135956598,0.7611948135956598,0.8572865600428173,0.8766427623609762,0.7262087842433007,0.470509404786824,0.470509404786824,0.6282351889284218,0.6017707521620771,0.7253787076291847,0.7253787076291847,0.6723636009918781,0.6723636009918781,0.2902922310728554,0.2902922310728554,0.7044434211243855,0.7044434211243855,0.5262837733774799,0.5262837733774799,0.5458425920040214,0.5458425920040214,0.6567950480611178,0.6567950480611178,0.6195998264083669,0.7929092801027591,0.7929092801027591,0.7718108090129557,0.6221616898989224,0.6221616898989224,0.6490553358057083,0.6490553358057083,0.5336296463277646,0.678868670711281,0.6106228510169052,0.7156284604360799,0.7156284604360799,0.7105180207026736,0.655401463634889,0.6245426870213623,0.6245426870213623,0.7717908603268143,0.7717908603268143,0.7065240451330159,0.6792448361684071,0.6975148792886434,0.6975148792886434,0.633720890439759,0.633720890439759,0.6224330055549917,0.6224330055549917,0.7107580 ...

# %% [markdown]
# ## Visualize PC90

# %%
### Worldbank country income classifications

# from here: https://datahelpdesk.worldbank.org/knowledgebase/articles/906519-world-bank-country-and-lending-groups
#  `current classification by income in XLSX format`
world_bank_mapping = pd.read_csv("WorldBank_CLASS.csv", encoding='latin-1')
world_bank_mapping
# Out:
#           Economy Code                      Region         Income group  \
# 0           Aruba  ABW   Latin America & Caribbean          High income
# 1     Afghanistan  AFG                  South Asia           Low income
# 2          Angola  AGO          Sub-Saharan Africa  Lower middle income
# 3         Albania  ALB       Europe & Central Asia  Upper middle income
# 4         Andorra  AND       Europe & Central Asia          High income
# ..            ...  ...                         ...                  ...
# 213        Kosovo  XKX       Europe & Central Asia  Upper middle income
# 214   Yemen, Rep.  YEM  Middle East & North Africa           Low income
# 215  South Africa  ZAF          Sub-Saharan Africa  Upper middle income
# 216        Zambia  ZMB          Sub-Saharan Africa           Low income
# 217      Zimbabwe  ZWE          Sub-Saharan Africa  Lower middle income
#
#     Lending category Other (EMU or HIPC)
# 0                NaN                 NaN
# 1                IDA                HIPC
# 2               IBRD                 NaN
# 3               IBRD                 NaN
# 4                NaN                 NaN
# ..               ...                 ...
# 213              IDA                 NaN
# 214              IDA                 NaN
# 215             IBRD                 NaN
# 216              IDA                HIPC
# 217            Blend                 NaN
#
# [218 rows x 6 columns]

# %%
def map_country_to_world_bank(country, wb_map):
    
    #adjust some country names
    if country == "England":
        country = "United Kingdom"
    if country == "Gaza":
        country = "West Bank and Gaza"
    if country == "Hong Kong":
        country = "Hong Kong SAR, China"
    if country == "Iran":
        country = "Iran, Islamic Rep."
    if country == "Ireland Northern" or country == "Ireland South":
        country = "Ireland"
    if country == "Russia":
        country = "Russian Federation"
    if country == "South Korea":
        country = "Korea, Rep."
    if country == "Taiwan":
        country = "Taiwan, China"
    if country == "Venezuela":
        country = "Venezuela, RB"
    
    wb_row = wb_map[wb_map["Economy"]==country]
    if wb_row.shape[0] > 0:
        return wb_row.iloc[0]["Income group"],wb_row.iloc[0]["Region"]
    else:
        return None, None

# %%
population_wb_income = pd.DataFrame({"population": pc90_results.population,
              "income_group": pc90_results.country.apply(lambda x: map_country_to_world_bank(x, world_bank_mapping)[0]),
              "region": pc90_results.country.apply(lambda x: map_country_to_world_bank(x, world_bank_mapping)[1])
             })
population_wb_income
# Out:
#                                   population         income_group  \
# 0                             American Samoa  Upper middle income
# 1                             American Samoa  Upper middle income
# 2    Australia Cape York Peninsula Aborigine          High income
# 3    Australia Cape York Peninsula Aborigine          High income
# 4         Australia Groote Eylandt Aborigine          High income
# ..                                       ...                  ...
# 509                             Vietnam Kinh  Lower middle income
# 510                            Zambia Lusaka           Low income
# 511                            Zambia Lusaka           Low income
# 512                    Zimbabwe Harare Shona  Lower middle income
# 513                    Zimbabwe Harare Shona  Lower middle income
#
#                   region
# 0    East Asia & Pacific
# 1    East Asia & Pacific
# 2    East Asia & Pacific
# 3    East Asia & Pacific
# 4    East Asia & Pacific
# ..                   ...
# 509  East Asia & Pacific
# 510   Sub-Saharan Africa
# 511   Sub-Saharan Africa
# 512   Sub-Saharan Africa
# 513   Sub-Saharan Africa
#
# [514 rows x 3 columns]

# %%
population_wb_income = population_wb_income.drop_duplicates().reset_index(drop=True)

# %%
dir_location_ms = "./pc90_afnd_ms_all_datasets"

# %%
dir_location_ba = "./pc90_afnd_ba_datasets"

# %%
pc90_ba_results = pd.read_csv(dir_location_ba+"/all_results.csv")
pc90_ms_results = pd.read_csv(dir_location_ms+"/all_results.csv")
pc90_ba_results["dataset"] = pc90_ba_results["dataset"].apply(lambda x: x+"_BA")
pc90_ms_results["dataset"] = pc90_ms_results["dataset"].apply(lambda x: x+"_MS")

# %%
#pc90_results = pd.read_csv(dir_location+"/all_results.csv")
pc90_results = pd.concat([pc90_ms_results, pc90_ba_results])

# %%
pc90_results["country"] = pc90_results.population.apply(lambda x: find_country_continent(pop_continent_map, x)[0])
pc90_results["continent"] =pc90_results.population.apply(lambda x: find_country_continent(pop_continent_map, x)[1])
pc90_results["income"] =  pc90_results.population.apply(lambda x: population_wb_income[population_wb_income.population == \
                                                                                      x].iloc[0].income_group)
pc90_results["wb_region"] =  pc90_results.population.apply(lambda x: population_wb_income[population_wb_income.population == \
                                                                                      x].iloc[0].region)

# %%
pc90_results[pc90_results["income"]=="Low income"].population.unique()
# Out:
# array(['Mali Bandiagara', 'Uganda Kampala', 'Uganda Kampala pop 2',
#        'Zambia Lusaka'], dtype=object)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(pc90_results[(pc90_results["income"]=="High income") & 
                 (pc90_results["dataset"]=="mhcflurry")].sort_values(by="pc90_scaled").reset_index(drop=True))
# Out:
#                                             population    dataset      pc90  \
# 0                         Australia Kimberly Aborigine  mhcflurry    548.32
# 1                         Australia Yuendumu Aborigine  mhcflurry    690.80
# 2                                 Singapore Riau Malay  mhcflurry   2729.25
# 3                             Singapore SGVP Malay MAS  mhcflurry   2936.49
# 4                                       Singapore Thai  mhcflurry   3262.34
# 5                                    USA NMDP Filipino  mhcflurry   3436.62
# 6              Israel Ashkenazi and Non Ashkenazi Jews  mhcflurry   4052.33
# 7                                  Singapore Javaneses  mhcflurry   4186.07
# 8                                  USA NMDP Vietnamese  mhcflurry   4281.06
# 9                           USA African American pop 3  mhcflurry   4747.93
# 10                                    USA NMDP African  mhcflurry   4871.37
# 11                  Australia Groote Eylandt Aborigine  mhcflurry   4973.37
# 12                             USA NMDP Caribean Black  mhcflurry   4978.54
# 13                                   Israel Arab Druze  mhcflurry   5009.38
# 14                                       New Caledonia  mhcflurry   5035.82
# 15             Australia Cape York Peninsula Aborigine  mhcflurry   5147.53
# 16                                          Taiwan Ami  mhcflurry   5218.25
# 17                                          Taiwan Tao  mhcflurry   5247.74
# 18                          USA African American pop 4  mhcflurry   5266.21
# 19                     USA NMDP African American pop 2  mhcflurry   5301.00
# 20                                       Taiwan Puyuma  mhcflurry   5307.05
# 21                       USA African American Bethesda  mhcflurry   5433.42
# 106       Europe & Central Asia
# 107               North America
# 108       Europe & Central Asia
# 109               North America
# 110       Europe & Central Asia
# 111               North America
# 112       Europe & Central Asia
# 113               North America
# 114       Europe & Central Asia
# 115         East Asia & Pacific
# 116               North America
# 117       Europe & Central Asia
# 118       Europe & Central Asia
# 119       Europe & Central Asia
# 120       Europe & Central Asia
# 121       Europe & Central Asia
# 122               North America
# 123       Europe & Central Asia
# 124               North America
# 125       Europe & Central Asia

# %%
population_counts = pc90_results[["population", "country"]].drop_duplicates().reset_index(drop=True).\
                    groupby(by="country").count().reset_index()[["country", "population"]].sort_values("population", \
                                                                                                        ascending=[False])

# %%
population_counts[:20]
# Out:
#              country  population
# 58     United States          46
# 11             China          27
# 54            Taiwan          17
# 26             India          12
# 37            Mexico          11
# 21           Germany          11
# 6             Brazil          10
# 12          Colombia          10
# 13        Costa Rica           6
# 44  Papua New Guinea           6
# 48            Russia           5
# 2          Australia           5
# 51      South Africa           5
# 50         Singapore           5
# 41       New Zealand           4
# 32             Japan           4
# 9             Canada           3
# 33             Kenya           3
# 8           Cameroon           3
# 38           Morocco           3

# %%
tmp_pop_country = pc90_results[["population", "country"]].drop_duplicates().reset_index(drop=True)
tmp_pop_country[tmp_pop_country["country"]=="South Africa"]
# Out:
#                        population       country
# 177       South Africa Caucasians  South Africa
# 178      South Africa Natal Tamil  South Africa
# 179        South Africa Worcester  South Africa
# 180           South African Black  South Africa
# 182  South African Mixed ancestry  South Africa

# %%
pc90_usa = pc90_results[pc90_results.population.apply(lambda x: "USA" in x)]

# %%
pc90_australia = pc90_results[pc90_results.population.apply(lambda x: "Australia" in x)]

# %%
pc90_brazil = pc90_results[pc90_results.country == "Brazil"]

# %%
def usa_population_ancestry(population):
    if "Caucasian" in population \
    or "Italy" in population or "European" in population :
        return "USA European"
    if "African" in population or "Caribbean" in population\
        or "Black" in population:
        return "USA African American"
    if "Asian" in population or "Japanese" in population \
        or "Korean" in population or "Vietnamese" in population:
        return "USA Asian"
    if "Hispanic" in population:
        return "USA Hispanic"
    return "Other"

def australia_population_ancs(population):
    if "Aborigine" in population:
        return "Aborigine"
    if "Caucasian" in population:
        return "European"
    return "Other"

def brazil_population_ancs(population):
    if "Black" in population:
        return "African"
    if "Caucasian" in population:
        return "European"
    if "Puyanawa" or "Terena" or "Ticuna" in population:
        return "Indigenous"
    return "Other"

# %%
pc90_brazil["ancestry"] = pc90_brazil.population.apply(lambda x: brazil_population_ancs(x))
# Out:
# <ipython-input-270-5d2add677874>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pc90_australia["ancestry"] = pc90_australia.population.apply(lambda x: australia_population_ancs(x))
# Out:
# <ipython-input-271-c2ecae0fa74d>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pc90_usa["ancestry"] = pc90_usa.population.apply(lambda x: usa_population_ancestry(x))
# Out:
# <ipython-input-353-74e214b5bea8>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pc90_results["PC90 (%)"] = pc90_results.pc90_scaled.apply(lambda x: x*100)

# %%
pc90_results["income-two"] = pc90_results["income"].apply(lambda x: "High and upper middle income" \
                                                          if x in ["High income", "Upper middle income"] \
                                                         else "Low and Lower middle income")

# %%
pc90_results = pc90_results[~pc90_results["income"].isna()]

# %%
income_ranks = {"High income": 1, \
               "Upper middle income": 2,\
               "Lower middle income": 3, \
               "Low income": 4}
pc90_results["income-rank"] = pc90_results["income"].apply(lambda x: income_ranks[x])
# Out:
# <ipython-input-326-8aa86cfb7a55>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset_names = {"netmhc_MS": "NetMHCpan4.1_MS", \
               "mhcflurry_MS": "MHCFlurry2.0_MS",\
               "netmhc_BA": "NetMHCpan4.1_BA", \
               "mhcflurry_BA": "MHCFlurry2.0_BA"}
dataset_ranks = {"netmhc_MS": 3, \
               "mhcflurry_MS": 4,\
               "netmhc_BA": 1, \
               "mhcflurry_BA": 2}
pc90_results["dataset_name"] = pc90_results["dataset"].apply(lambda x: dataset_names[x])
pc90_results["dataset_ranks"] = pc90_results["dataset"].apply(lambda x: dataset_ranks[x])
# Out:
# <ipython-input-337-f1aed807d8eb>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-337-f1aed807d8eb>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.box(pc90_results.sort_values(by=["income-rank", "dataset_ranks"]), #pc90_brazil[~(pc90_brazil["ancestry"]=="Other")], \
             x="dataset_name", y="PC90 (%)", color="income",width=1000, height=500, points="all",\
              hover_data=["population"], \
            color_discrete_sequence=px.colors.qualitative.Safe)
#fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
fig.update_layout(yaxis_range=[0, 9.5],
                  boxgroupgap=0.4, # update
                  boxgap=0.1)
fig.show()
# Out:
# <div>                            <div id="9d039ad5-c9fa-4373-a660-07f858f26c5a" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d039ad5-c9fa-4373-a660-07f858f26c5a")) {                    Plotly.newPlot(                        "9d039ad5-c9fa-4373-a660-07f858f26c5a",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[["Australia Cape York Peninsula Aborigine"],["Australia Groote Eylandt Aborigine"],["Australia Kimberly Aborigine"],["Australia New South Wales Caucasian"],["Australia Yuendumu Aborigine"],["Canada Chipewyan NA-DHS_2 (G)"],["Canada Cree NA-DHS_3 (G)"],["Canada Ojibwa NA-DHS_4 (G)"],["Chile Easter Island"],["Chile Huilliche NA-DHS_14 (G)"],["Czech Republic NMDR"],["England Blood Donors of Mixed Ethnicity"],["England North West"],["Finland"],["France Southeast"],["Germany DKMS - Austria minority"],["Germany DKMS - Croatia minority"],["Germany DKMS - France minority"],["Germany DKMS - German donors"],["Germany DKMS - Greece minority"],["Germany DKMS - Italy minority"],["Germany DKMS - Netherlands minority"],["Germany DKMS - Portugal minority"],["Germany DKMS - Romania minority"],["Germany DKMS - Spain minority"],["Germany DKMS - Turkey minority"],["Germany DKMS - United Kingdom minority"],["Germany pop 6"],["Germany pop 8"],["Greece pop 6"],["Greece pop 8"],["Hong Kong Chinese BMDR"],["Hong Kong Chinese HKBMDR HLA 11 loci"],["Ireland Northern"],["Ireland South"],["Israel Arab Druze"],["Israel Ashkenazi and Non Ashkenazi Jews"],["Italy pop 5"],["Japan Central"],["Japan pop 16"],["Japan pop 3"],["Japan pop 5"],["Netherlands Leiden"],["Netherlands UMCU"],["New Caledonia"],["New Zealand Maori with Admixed History"],["New Zealand Maori with Full Ancestry"],["New Zealand Polynesians with Admixed History"],["New Zealand Polynesians with Full Ancestry"],["Panama"],["Poland"],["Poland BMR"],["Poland DKMS"],["Portugal Azores Terceira Island"],["Saudi Arabia Guraiat and Hail"],["Saudi Arabia pop 6 (G)"],["Singapore Javaneses"],["Singapore Riau Malay"],["Singapore SGVP Chinese CHS"],["Singapore SGVP Malay MAS"],["Singapore Thai"],["South Korea pop 3"],["Taiwan Ami"],["Taiwan Atayal"],["Taiwan Bunun"],["Taiwan Hakka"],["Taiwan Han Chinese"],["Taiwan Minnan pop 1"],["Taiwan Paiwan"],["Taiwan Pazeh"],["Taiwan Puyuma"],["Taiwan Rukai"],["Taiwan Saisiat"],["Taiwan Siraya"],["Taiwan Tao"],["Taiwan Taroko"],["Taiwan Thao"],["Taiwan Tsou"],["Taiwan pop 2"],["USA African American"],["USA African American Bethesda"],["USA African American pop 3"],["USA African American pop 4"],["USA Alaska Yupik"],["USA Arizona Gila River Amerindian"],["USA Arizona Gila River Pima"],["USA Asian"],["USA Asian pop 2"],["USA Caucasian Bethesda"],["USA Caucasian pop 2"],["USA Caucasian pop 4"],["USA Eastern European"],["USA Hawaii Okinawa"],["USA Hispanic"],["USA Hispanic pop 2"],["USA Italy Ancestry"],["USA Mexican American Mestizo"],["USA NMDP African"],["USA NMDP African American pop 2"],["USA NMDP Alaska Native or Aleut"],["USA NMDP American Indian South or Central America"],["USA NMDP Caribean Black"],["USA NMDP Caribean Hispanic"],["USA NMDP Caribean Indian"],["USA NMDP Chinese"],["USA NMDP European Caucasian"],["USA NMDP Filipino"],["USA NMDP Hawaiian or other Pacific Islander"],["USA NMDP Hispanic South or Central American"],["USA NMDP Japanese"],["USA NMDP Korean"],["USA NMDP Mexican or Chicano"],["USA NMDP Middle Eastern or North Coast of Africa"],["USA NMDP North American Amerindian"],["USA NMDP South Asian Indian"],["USA NMDP Southeast Asian"],["USA NMDP Vietnamese"],["USA New Mexico Canoncito Navajo"],["USA North American Native"],["USA Philadelphia Caucasian"],["USA San Antonio Caucasian"],["USA San Diego"],["USA San Francisco Caucasian"],["USA South Dakota Lakota Sioux"],["USA S ...

# %%
fig.write_image("PC90_incomes.svg", width=1000, height=500)

# %%
fig = px.box(pc90_results.sort_values(by=["income-rank", "dataset_ranks"]), #pc90_brazil[~(pc90_brazil["ancestry"]=="Other")], \
             x="dataset_name", y="PC90 (%)", color="wb_region",width=1000, height=500, #points="all",\
              hover_data=["population"], \
            color_discrete_sequence=px.colors.qualitative.Vivid)
#fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
fig.show()
# Out:
# <div>                            <div id="4ca0f319-a2c3-4aa0-8974-6b3c070944d4" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ca0f319-a2c3-4aa0-8974-6b3c070944d4")) {                    Plotly.newPlot(                        "4ca0f319-a2c3-4aa0-8974-6b3c070944d4",                        [{"alignmentgroup":"True","customdata":[["Australia Cape York Peninsula Aborigine"],["Australia Groote Eylandt Aborigine"],["Australia Kimberly Aborigine"],["Australia New South Wales Caucasian"],["Australia Yuendumu Aborigine"],["Hong Kong Chinese BMDR"],["Hong Kong Chinese HKBMDR HL
ape York Peninsula Aborigine"],["Australia Groote Eylandt Aborigine"],["Australia Kimberly Aborigine"],["Australia New South Wales Caucasian"],["Australia Yuendumu Aborigine"],["Hong Kong Chinese BMDR"],["Hong Kong Chinese HKBMDR HLA 11 loci"],["Japan Central"],["Japan pop 16"],["Japan pop 3"],["Japan pop 5"],["New Caledonia"],["New Zealand Maori with Admixed History"],["New Zealand Maori with Full Ancestry"],["New Zealand Polynesians with Admixed History"],["New Zealand Polynesians wi ...

# %%
ancs_ranks = {"USA African American": 1, \
               "USA Asian": 2,\
               "USA Hispanic": 3, \
               "USA European": 4, \
             "Other": 5}
pc90_usa["ansc_rank"] = pc90_usa["ancestry"].apply(lambda x: ancs_ranks[x])
# Out:
# <ipython-input-594-cc3e84adfd7c>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.box(pc90_usa[~(pc90_usa["ancestry"]=="Other")].sort_values(by=["dataset_ranks", "ansc_rank"], \
                                                                    ascending = [True, False]), #pc90_results[pc90_results.country == "Mexico"], #pc90_brazil[~(pc90_brazil["ancestry"]=="Other")], \
             x="dataset_name", y="PC90 (%)", color="ancestry",width=900, height=500, points="all",
              hover_data=["population"], \
            color_discrete_sequence=px.colors.sequential.ice[2::2])
#fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
fig.update_layout(yaxis_range=[0, 9.5])
fig.show()
# Out:
# <div>                            <div id="761cda48-04eb-4682-9b00-79b41b50be6e" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("761cda48-04eb-4682-9b00-79b41b50be6e")) {                    Plotly.newPlot(                        "761cda48-04eb-4682-9b00-79b41b50be6e",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[["USA Caucasian Bethesda"],["USA Caucasian pop 2"],["USA Caucasian pop 4"],["USA Eastern European"],["USA Italy Ancestry"],["USA NMDP European Caucasian"],["USA Philadelphia Caucasian"],["USA San Antonio Caucasian"],["USA San Francisco Caucasian"],["USA Caucasian Bethesda"],["USA Caucasian pop 2"],["USA Caucasian pop 4"],["USA Eastern European"],["USA Italy Ancestry"],["USA NMDP European Caucasian"],["USA Philadelphia Caucasian"],["USA San Antonio Caucasian"],["USA San Francisco Caucasian"],["USA Caucasian Bethesda"],["USA Caucasian pop 2"],["USA Caucasian pop 4"],["USA Eastern European"],["USA Italy Ancestry"],["USA NMDP European Caucasian"],["USA Philadelphia Caucasian"],["USA San Antonio Caucasian"],["USA San Francisco Caucasian"],["USA Caucasian Bethesda"],["USA Caucasian pop 2"],["USA Caucasian pop 4"],["USA Eastern European"],["USA Italy Ancestry"],["USA NMDP European Caucasian"],["USA Philadelphia Caucasian"],["USA San Antonio Caucasian"],["USA San Francisco Caucasian"]],"hovertemplate":"ancestry=USA European<br>dataset_name=%{x}<br>PC90 (%)=%{y}<br>population=%{customdata[0]}<extra></extra>","legendgroup":"USA European","marker":{"color":"rgb(44, 42, 87)"},"name":"USA European","notched":false,"offsetgroup":"USA European","orientation":"v","showlegend":true,"type":"box","x":["NetMHCpan4.1_BA","NetMHCpan4.1_BA","NetMHCpan4.1_BA","NetMHCpan4.1_BA","NetMHCpan4.1_BA","NetMHCpan4.1_BA","NetMHCpan4.1_BA","NetMHCpan4.1_BA","NetMHCpan4.1_BA","MHCFlurry2.0_BA","MHCFlurry2.0_BA","MHCFlurry2.0_BA","MHCFlurry2.0_BA","MHCFlurry2.0_BA","MHCFlurry2.0_BA","MHCFlurry2.0_BA","MHCFlurry2.0_BA","MHCFlurry2.0_BA","NetMHCpan4.1_MS","NetMHCpan4.1_MS","NetMHCpan4.1_MS","NetMHCpan4.1_MS","NetMHCpan4.1_MS","NetMHCpan4.1_MS","NetMHCpan4.1_MS","NetMHCpan4.1_MS","NetMHCpan4.1_MS","MHCFlurry2.0_MS","MHCFlurry2.0_MS","MHCFlurry2.0_MS","MHCFlurry2.0_MS","MHCFlurry2.0_MS","MHCFlurry2.0_MS","MHCFlurry2.0_MS","MHCFlurry2.0_MS","MHCFlurry2.0_MS"],"x0":" ","xaxis":"x","y":[6.01055806051485,6.2035248402476,6.56659044013473,5.81445208016131,5.735025601533151,6.44216875260865,4.60672988178029,6.156301621920321,6.307324213583209,6.129418121318779,6.1950045204328905,6.6604218714057195,5.88449625258788,5.74121190398493,6.48332254492347,4.592968453263,6.18054983442911,6.318067287579771,7.3629260297657995,7.364351882425691,8.07418336165026,6.86804709216111,6.563220806042009,7.818709588333821,5.76337749974484,7.70361476162745,7.464593827108611,5.66705649056795,5.71324475595589,6.09414833907639,5.37247087076751,5.2581031872993,5.98287056412342,4.7484051769657105,5.83480332145609,5.79910705555186],"y0":" ","yaxis":"y"},{"alignmentgroup":"True","boxpoints":"all","customdata":[["USA Hispanic"],["USA Hispanic pop 2"],["USA NMDP Caribean Hispanic"],["USA NMDP Hispanic South or Central American"],["USA South Texas Hispanic"],["USA Hispanic"],["USA Hispanic pop 2"],["USA NMDP Caribean Hispanic"],["USA NMDP Hispanic South or Central American"],["USA South Texas Hispanic"],["USA Hispanic"],["USA Hispanic pop 2"],["USA NMDP Caribean Hispanic"],["USA NMDP Hispanic South or Central American"],["USA South Texas Hispanic"],["USA Hispanic"],["USA Hispanic pop 2"],["USA NMDP Caribean Hispanic"],["USA NMDP Hispanic South or Central American"],["USA South Texas Hispanic"]],"hovertemplate":"ancestry=USA Hispanic<br>dataset_name=%{x}<br>PC90 (%)=%{y}<br>population=%{customdata[0]}<extra></extra>","legendgro ...

# %%
fig.write_image("PC90_usa_ancs.svg", width=900, height=500)

# %%
fig = px.scatter(pc90_australia, #[~(pc90_usa["ancestry"]=="Other")], \
             x="population", y="pc90_scaled", color="dataset_name",width=700, height=500)
#fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-768-2738fc57755f> in <module>
# ----> 1 fig = px.scatter(pc90_australia, #[~(pc90_usa["ancestry"]=="Other")], \
#       2              x="population", y="pc90_scaled", color="dataset_name",width=700, height=500)
#       3 #fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
#       4 fig.show()
#
# ~\Miniconda3\lib\site-packages\plotly\express\_chart_types.py in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#      67
#      68
#
# ~\Miniconda3\lib\site-packages\plotly\express\_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    1931     apply_default_cascade(args)
#    1932
# -> 1933     args = build_dataframe(args, constructor)
#    1934     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1935         args = process_dataframe_hierarchy(args)
#
# ~\Miniconda3\lib\site-packages\plotly\express\_core.py in build_dataframe(args, constructor)
#    1403     # now that things have been prepped, we do the systematic rewriting of `args`
#    1404
# -> 1405     df_output, wide_id_vars = process_args_into_dataframe(
#    1406         args, wide_mode, var_name, value_name
#    1407     )
#
# ~\Miniconda3\lib\site-packages\plotly\express\_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205                         if argument == "index":
#    1206                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207                         raise ValueError(err_msg)
#    1208                 elif length and len(df_input[argument]) != length:
#    1209                     raise ValueError(
#
# ValueError: Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['population', 'dataset', 'pc90', 'average_hits', 'pc90_scaled', 'average_hits_scaled', 'country', 'continent', 'income', 'wb_region', 'ancestry'] but received: dataset_name

# %%
region_ranks_map = {
    "Europe": .0,
    "North America": 1,
    "South America": 2,
    "Asia": 3,
    "Oceania": 4,
    "Africa": 5   
}
pc90_results["continent_ranks"] = pc90_results["continent"].apply(lambda x: region_ranks_map[x])

# %%
afdn_regions = pd.read_csv("./country_region_map.csv")

# %%
afdn_regions[afdn_regions["region"]=="Oceania"].country.unique()
# Out:
# array([nan, 'American Samoa', 'Borneo', 'Bouvet Island',
#        'British Indian Ocean Territory', 'Christmas Island',
#        'Cocos Islands', 'Cook Islands', 'East Timor',
#        'Federal States of Micronesia', 'Fiji', 'French Polynesia',
#        'French Southern Territories', 'Guam',
#        'Heard and Mc Donald Islands', 'Indonesia', 'Kiribati',
#        'Madagascar', 'Maldives', 'Marshall Islands', 'Nauru',
#        'New Caledonia', 'New Zealand', 'Niue', 'Norfolk Island',
#        'Northern Mariana Islands', 'Palau', 'Papua New Guinea',
#        'Philippines', 'Pitcairn Islands', 'Samoa', 'Solomon Islands',
#        'Timor-Leste', 'Tokelau', 'Tonga', 'Tuvalu', 'Vanuatu',
#        'Wallis and Futuna Islands'], dtype=object)

# %%
def map_afnd_region(x, afdn_regions):
    tmp =  afdn_regions[afdn_regions["country"]==x].region
    if tmp.shape[0] > 0:
        return tmp.iloc[0]
    else:
        if "Kosovo" in x or "Ireland" in x:
            return "Europe"
        return None

# %%
pc90_results["afnd_region"] = pc90_results.country.apply(lambda x: map_afnd_region(x, afdn_regions))

# %%
fig = px.box(pc90_results.sort_values(by=["dataset_ranks", "continent_ranks"], ascending = [True, True]), \
             x="dataset_name", y="PC90 (%)", color="afnd_region", width=1000, height=500, #points="all", \
             #boxmode="overlay",\ 
            hover_data=["population"], color_discrete_sequence=px.colors.qualitative.Dark24)
#fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
'''
fig = px.box(pc90_usa[~(pc90_usa["ancestry"]=="Other")].sort_values(by=["dataset_ranks", "ansc_rank"], \
                                                                    ascending = [True, False]), #pc90_results[pc90_results.country == "Mexico"], #pc90_brazil[~(pc90_brazil["ancestry"]=="Other")], \
             x="dataset_name", y="PC90 (%)", color="ancestry",width=900, height=500, points="all",
              hover_data=["population"], marker_line\
            color_discrete_sequence=px.colors.sequential.ice[4::2])
'''
#fig.add_hline(y=1, line_width=2, line_dash="dash", line_color="red")
fig.update_layout(yaxis_range=[0, 9.5],
                  boxgroupgap=0.5, #boxmode = "overlay",# update
                  boxgap=0.2)
fig.show()
# Out:
# <div>                            <div id="35803467-5b1d-4098-b45e-3844fe1531d5" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
MS - France minority"],["Germany DKMS - German donors"],["Germany DKMS - Greece minority"],["Germany DKMS - Italy minority"],["Germany DKMS - Netherlands minority"],["Germany DKMS - Portugal minority"],["Germany DKMS - Romania minority"],["Germany DKMS - Spain minority"],["Germany DKMS - Turkey minority"],["Germany DKMS - United Kingdom minority"],["Germany pop 6"],["Germany pop 8"],["Greece pop 6"],["Greece pop 8"],["Ireland Northern"],["Ireland South"],["Italy pop 5"],["Kosovo"],[" ...

# %%
fig.write_image("PC90_global_regions.svg", width=900, height=500)

# %%
pc90_results["GlobalSouth/GlobalNorth"] = pc90_results.population.apply(lambda x: gn_gs_map[x])

# %%
fig = px.box(pc90_results, x="GlobalSouth/GlobalNorth", y="pc90", \
             color="dataset",width=650, height=500, orientation="v")
fig.show()
# Out:
# <div>                            <div id="1a48bf5b-56aa-4d90-beb0-001d89627d17" class="plotly-graph-div" style="height:500px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a48bf5b-56aa-4d90-beb0-001d89627d17")) {                    Plotly.newPlot(                        "1a48bf5b-56aa-4d90-beb0-001d89627d17",                        [{"alignmentgroup":"True","hovertemplate":"dataset=mhcflurry<br>GlobalSouth/GlobalNorth=%{x}<br>pc90=%{y}<extra></extra>","legendgroup":"mhcflurry","marker":{"color":"#636efa"},"name":"mhcflurry","notched":false,"offsetgroup":"mhcflurry","orientation":"v","showlegend":true,"type":"box","x":["Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global South","Global North","Global South","Global South","Global North","Global South","Global South","Global South","Global North","Global North","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global South","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global South","Global North","Global North","Global South","Global North","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global South","Global South","Global South","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global North","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global South","Global South","Global South","Global North","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global South","Global North","Global North","Global North","Global South","Global Sout ...

# %%
pc90_results[(pc90_results["dataset"] == "mhcflurry_BA") & \
            (pc90_results["income"] == "Lower middle income")].sort_values(by=["pc90_scaled"])
# Out:
#                                           population       dataset      pc90  \
# 214                           India West Coast Parsi  mhcflurry_BA    419.25
# 34                               Cameroon Baka Pygmy  mhcflurry_BA   1136.59
# 38                                     Cameroon Sawa  mhcflurry_BA   1616.95
# 508                                     Vietnam Kinh  mhcflurry_BA   2667.85
# 238                                            Kenya  mhcflurry_BA   3141.33
# 240                                        Kenya Luo  mhcflurry_BA   3359.97
# 404                                  Tanzania Maasai  mhcflurry_BA   3730.11
# 512                            Zimbabwe Harare Shona  mhcflurry_BA   3743.36
# 506                         Vietnam Hanoi Kinh pop 2  mhcflurry_BA   3854.98
# 302         Papua New Guinea East New Britain Rabaul  mhcflurry_BA   4143.94
# 36                                     Cameroon Beti  mhcflurry_BA   4191.27
# 242                                      Kenya Nandi  mhcflurry_BA   4246.03
# 218                                      Iran Gorgan  mhcflurry_BA   4429.15
# 206                             India Mumbai Maratha  mhcflurry_BA   4887.82
# 216                                      Iran Baloch  mhcflurry_BA   4957.41
# 310     Papua New Guinea West Schrader Ranges Haruai  mhcflurry_BA   4972.72
# 304  Papua New Guinea Eastern Highlands Goroka Asaro  mhcflurry_BA   4973.55
# 202      14607.11     0.033882             0.078143             India
# 350      14361.09     0.034021             0.076826             India
# 12       21344.38     0.034129             0.114184           Bolivia
# 276      16130.49     0.034270             0.086292           Morocco
# 280      16130.49     0.034270             0.086292           Morocco
# 210      14218.16     0.035021             0.076062             India
# 278      16725.39     0.035475             0.089475           Morocco
# 296      17259.21     0.036750             0.092330         Nicaragua
# 308       9501.44     0.037794             0.050829  Papua New Guinea
# 298      17893.22     0.038918             0.095722         Nicaragua
# 208      15005.98     0.039782             0.080276             India
# 212      18899.51     0.053836             0.101105             India
# 14       22897.80     0.060170             0.122495           Bolivia
#
#          continent               income                   wb_region
# 214           Asia  Lower middle income                  South Asia
# 34          Africa  Lower middle income          Sub-Saharan Africa
# 38          Africa  Lower middle income          Sub-Saharan Africa
# 508           Asia  Lower middle income         East Asia & Pacific
# 238         Africa  Lower middle income          Sub-Saharan Africa
# 240         Africa  Lower middle income          Sub-Saharan Africa
# 404         Africa  Lower middle income          Sub-Saharan Africa
# 512         Africa  Lower middle income          Sub-Saharan Africa
# 506           Asia  Lower middle income         East Asia & Pacific
# 302        Oceania  Lower middle income         East Asia & Pacific
# 36          Africa  Lower middle income          Sub-Saharan Africa
# 242         Africa  Lower middle income          Sub-Saharan Africa
# 218           Asia  Lower middle income  Middle East & North Africa
# 206           Asia  Lower middle income                  South Asia
# 216           Asia  Lower middle income  Middle East & North Africa
# 310        Oceania  Lower middle income         East Asia & Pacific
# 304        Oceania  Lower middle income         East Asia & Pacific
# 186         Africa  Lower middle income          Sub-Saharan Africa
# 306        Oceania  Lower middle income         East Asia & Pacific
# 362           Asia  Lower middle income                  South Asia
# 318           Asia  Lower middle income         East Asia & Pacific
# 368           Asia  Lower middle income                  South Asia
# 312        Oceania  Lower middle income         East Asia & Pacific
# 200           Asia  Lower middle income                  South Asia
# 204           Asia  Lower middle income                  South Asia
# 148           Asia  Lower middle income  Middle East & North Africa
# 198           Asia  Lower middle income                  South Asia
# 248           Asia  Lower middle income                  South Asia
# 202           Asia  Lower middle income                  South Asia
# 350           Asia  Lower middle income                  South Asia
# 12   South America  Lower middle income   Latin America & Caribbean
# 276         Africa  Lower middle income  Middle East & North Africa
# 280         Africa  Lower middle income  Middle East & North Africa
# 210           Asia  Lower middle income                  South Asia
# 278         Africa  Lower middle income  Middle East & North Africa
# 296  North America  Lower middle income   Latin America & Caribbean
# 308        Oceania  Lower middle income         East Asia & Pacific
# 298  North America  Lower middle income   Latin America & Caribbean
# 208           Asia  Lower middle income                  South Asia
# 212           Asia  Lower middle income                  South Asia
# 14   South America  Lower middle income   Latin America & Caribbean

# %%
pd.read_csv(file, nrows=1, skiprows=1, sep="\t")
# Out:
#   population/area coverage  average_hit     pc90
# 0  American Samoa   100.0%       5926.3  3013.05

# %%
#pop_continent_map["Population"] = pop_continent_map["Population"].apply(lambda x: x.replace(" ", "").replace("/", ""))
#result_df_afnd.population = result_df_afnd.population.apply(lambda x: x.replace("_", "").replace(" ", "").replace("/", ""))
